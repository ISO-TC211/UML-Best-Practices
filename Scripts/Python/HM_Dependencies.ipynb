# %% [markdown]
# # ISO TC/211 Harmonised Model Dependency Controls

# %% [markdown]
# Connect to the EA app and model repository

# %%
from Parameters import *
from EAConnect import *
from HM_Controls import *
import sys
import pandas as pd

# Open EA Repository and find Model
eaApp = openEAapp()
eaRepo = openEArepo(eaApp,repo_path)
try:
    cmMod = eaRepo.Models.GetByName(modelName)
    printTS('Model "' + modelName + '" found with PackageGUID ' + cmMod.PackageGUID )
    printTS('Number of main packages: ' + str(cmMod.Packages.Count))
except Exception as e:
    printTS('Model  "' + modelName + '" not found!')
    # closeEA(eaRepo)
    # sys.exit()

timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# 2025-02-25 12:35:37   Hi EA - are you there?
# 2025-02-25 12:35:37   I am here
# 2025-02-25 12:35:37   Hi EA - Please open this repository: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\ISOTC211_HM EditorialVersion.qea
# 2025-02-25 12:35:38   OK! Repository C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\ISOTC211_HM EditorialVersion.qea is ready!
# 2025-02-25 12:35:38   Model "Conceptual Models" found with PackageGUID {7B6B28E9-C583-4363-9E9C-F37A37AE06C9}
# 2025-02-25 12:35:38   Number of main packages: 5

# %% [markdown]
# Get the TC 211 main package

# %%
tcmName = 'ISO TC211'
try:
    tcMod = cmMod.Packages.GetByName(tcmName)
    printTS('Model "' + tcmName + '" found with PackageGUID ' + tcMod.PackageGUID )
except Exception as e:
    printTS('Model  "' + tcmName + '" not found!')

printTS('Number of main packages: ' + str(tcMod.Packages.Count))
# Out:
# 2025-02-25 12:35:40   Model "ISO TC211" found with PackageGUID {CAB2E56D-50FA-4904-A16C-B34D7AE325B6}
# 2025-02-25 12:35:40   Number of main packages: 59

# %% [markdown]
#  # Create DataFrames for elements and properties
#  - Loop through the complete model:
#     - For each element: add content to rows for ElementID, GUID, main standard, standard and element name
#     - For each attribute or association end: add content to rows for elementID, GUID, main standard, standard, attribute/association name and refElementID

# %%
def recElements(pck,df):
    for eaEl in pck.Elements:
        # print('Element: ' + el.Name)
        if eaEl.Type.upper() in ["CLASS","INTERFACE", "DATATYPE","ENUMERATION"]:
           df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID, edPck.Name,eaEl.Name,eaEl.Type] 

    for p in pck.Packages:
        recElements(p,df)
    return df

dfEl = pd.DataFrame(columns=['ElementID','GUID','msGUID','MainStandard','edGUID', 'Edition', 'ElementName','Type'])
for stPck in tcMod.Packages:
    printTS('Standard: ' + stPck.Name)
    for edPck in stPck.Packages:
        printTS('Edition: ' + edPck.Name)
        dfEl = recElements(edPck,dfEl)
# Out:
# 2025-02-25 12:35:54   Standard: Common types
# 2025-02-25 12:35:54   Standard: Package Context Diagrams
# 2025-02-25 12:35:54   Standard: ISO 6709 Standard representation of geographic point location by coordinates
# 2025-02-25 12:35:54   Edition: ISO 6709 Edition 2
# 2025-02-25 12:35:54   Edition: ISO 6709 Edition 1 (Corrigendum 1)
# 2025-02-25 12:35:54   Standard: ISO 19101 Reference model
# 2025-02-25 12:35:54   Edition: ISO 19101-1 Edition 1
# 2025-02-25 12:35:54   Edition: ISO 19101-2 Edition 1
# 2025-02-25 12:35:54   Edition: ISO/TS 19101-2 Edition 1
# 2025-02-25 12:35:54   Standard: ISO 19103 Conceptual schema language
# 2025-02-25 12:35:54   Edition: ISO 19103 Edition 2
# 2025-02-25 12:35:55   Edition: ISO 19103 Edition 2 Informative content
# 2025-02-25 12:35:55   Edition: ISO 19103 Edition 1
# 2025-02-25 12:35:56   Edition: ISO TS 19103 Edition 1
# 2025-02-25 12:35:56   Standard: ISO 19104 Terminology
# 2025-02-25 12:35:56   Edition: ISO 19104 Edition 1
# 2025-02-25 12:35:56   Standard: ISO 19105 Conformance and testing
# 2025-02-25 12:35:56   Edition: ISO 19105-2 Extended for normative statements
# 2025-02-25 12:35:57   Edition: ISO 19105 Edition 2
# 2025-02-25 12:35:57   Standard: ISO 19107 Spatial schema
# 2025-02-25 12:35:57   Edition: Informative Annex to Spatial Schema
# 2025-02-25 12:35:57   Edition: Possible Excess Model Elements
# 2025-02-25 12:35:57   Edition: WKT for Features and their Geometry
# 2025-02-25 12:35:57   Edition: ISO 19107 Edition 2
# 2025-02-25 12:35:58   Edition: ISO 19107 Edition 1
# 2025-02-25 12:35:59   Standard: ISO 19108 Temporal schema
# 2025-02-25 12:35:59   Edition: ISO 19108 Edition 1
# 2025-02-25 12:35:59   Standard: ISO 19109 Rules for application schema
# 2025-02-25 12:35:59   Edition: ISO/FDIS 19109 Edition 3
# 2025-02-25 12:35:59   Edition: ISO/FDIS 19109 Edition 3 Informative content
# 2025-02-25 12:36:00   Edition: ISO 19109 Edition 2
# 2025-02-25 12:36:00   Edition: ISO 19109 Edition 1
# 2025-02-25 12:36:01   Standard: ISO 19110 Methodology for feature cataloguing
# 2025-02-25 12:36:01   Edition: ISO 19110 Edition 2
# 2025-02-25 12:36:01   Edition: ISO 19110 Edition 1
# 2025-02-25 12:36:01   Standard: ISO 19111 Referencing by coordinates
# 2025-02-25 12:36:01   Edition: ISO 19111 Edition 3 (Amendment 2)
# 2025-02-25 12:36:01   Edition: ISO 19111 Edition 3 (Amendment 1)
# 2025-02-25 12:36:02   Edition: ISO 19111 Edition 3
# 2025-02-25 12:36:02   Edition: ISO 19111 Edition 2
# 2025-02-25 12:36:02   Edition: ISO 19111-2 Edition 1
# 2025-02-25 12:36:02   Standard: ISO 19112 Spatial referencing by geographic identifier
# 2025-02-25 12:36:02   Edition: ISO 19112 Edition 1
# 2025-02-25 12:36:02   Edition: ISO 19112 Edition 2
# 2025-02-25 12:36:02   Standard: ISO 19115 Metadata
# 2025-02-25 12:36:02   Edition: ISO 19115-1 Edition 1 (Complete)
# 2025-02-25 12:36:03   Edition: ISO 19115-2 Edition 2 (Complete)
# 2025-02-25 12:36:03   Edition: ISO 19115-1 Edition 1 (Amendment 2)
# 2025-02-25 12:36:03   Edition: ISO 19115-1 Edition 1
# 2025-02-25 12:36:04   Edition: ISO 19115-1 Edition 1 (Amendment 1)
# 2025-02-25 12:36:04   Edition: ISO 19115-2 Edition 2 (Amendment 1)
# 2025-02-25 12:36:04   Edition: ISO 19115-2 Edition 2
# 2025-02-25 12:36:05   Edition: ISO 19115 Edition 1 (Corrigendum 1)
# 2025-02-25 12:36:05   Edition: ISO 19115-2 Edition 1
# 2025-02-25 12:36:05   Edition: ISO 19115 Edition 1
# 2025-02-25 12:36:06   Standard: ISO 19116 Positioning services
# 2025-02-25 12:36:06   Edition: ISO/FDIS 19116 Edition 3
# 2025-02-25 12:36:06   Edition: ISO 19116 Edition 2 (Amendment 1)
# 2025-02-25 12:36:06   Edition: ISO 19116 Edition 2
# 2025-02-25 12:36:07   Edition: ISO 19116 Edition 1
# 2025-02-25 12:36:07   Standard: ISO 19117 Portrayal
# 2025-02-25 12:36:07   Edition: ISO 19117 Edition 2
# 2025-02-25 12:36:07   Edition: ISO 19117 Edition 1
# 2025-02-25 12:36:07   Standard: ISO 19118 Encoding
# 2025-02-25 12:36:07   Edition: ISO 19118 Edition 2
# 2025-02-25 12:36:07   Edition: ISO 19118 Edition 1
# 2025-02-25 12:36:07   Standard: ISO 19119 Services
# 2025-02-25 12:36:07   Edition: ISO 19119 Edition 2
# 2025-02-25 12:36:07   Edition: ISO 19119 Edition 1 (Amendment 1)
# 2025-02-25 12:36:07   Edition: ISO 19119 Edition 1
# 2025-02-25 12:36:08   Standard: ISO 19123 Schema for coverage geometry and functions
# 2025-02-25 12:36:08   Edition: ISO/DTS 19123-4 Edition 1
# 2025-02-25 12:36:08   Edition: ISO/CD 19123-2 Edition 2
# 2025-02-25 12:36:08   Edition: ISO 19123-1 Edition 1
# 2025-02-25 12:36:08   Edition: ISO 19123-2 Edition 1
# 2025-02-25 12:36:08   Edition: ISO 19123-3 Edition 1
# 2025-02-25 12:36:08   Edition: ISO 19123 Edition 1
# 2025-02-25 12:36:09   Standard: ISO 19124 Calibration and validation of remote sensing data and derived products
# 2025-02-25 12:36:09   Edition: ISO TS 19124-1 Edition 1
# 2025-02-25 12:36:09   Edition: ISO/AWI TS 19124-2 Edition 1
# 2025-02-25 12:36:09   Standard: ISO 19125 Simple feature access
# 2025-02-25 12:36:09   Edition: ISO 19125-1 Edition 2
# 2025-02-25 12:36:09   Edition: ISO 19125-1 Edition 1
# 2025-02-25 12:36:09   Standard: ISO 19126 Feature concept dictionaries and registers
# 2025-02-25 12:36:09   Edition: ISO 19126 Edition 2
# 2025-02-25 12:36:09   Edition: ISO 19126 Edition 1
# 2025-02-25 12:36:09   Standard: ISO 19128 Web map server interface
# 2025-02-25 12:36:09   Edition: ISO 19128 Edition 1
# 2025-02-25 12:36:09   Standard: ISO 19129 Imagery, gridded and coverage data framework
# 2025-02-25 12:36:09   Edition: ISO 19129 Edition 1
# 2025-02-25 12:36:09   Standard: ISO 19130 Imagery sensor models for geopositioning
# 2025-02-25 12:36:09   Edition: ISO/CD 19130-2 Edition 2
# 2025-02-25 12:36:10   Edition: ISO 19130-1 Edition 1
# 2025-02-25 12:36:10   Edition: ISO 19130 Edition 1
# 2025-02-25 12:36:10   Edition: ISO 19130-2 Edition 1
# 2025-02-25 12:36:10   Standard: ISO 19131 Data product specifications
# 2025-02-25 12:36:10   Edition: ISO 19131 Edition 2
# 2025-02-25 12:36:11   Edition: ISO 19131 Edition 1
# 2025-02-25 12:36:11   Standard: ISO 19132 Location-based services - Reference model
# 2025-02-25 12:36:11   Edition: ISO 19132 Edition 1
# 2025-02-25 12:36:11   Standard: ISO 19133 Location-based services - Tracking and navigation
# 2025-02-25 12:36:11   Edition: ISO 19133 Edition 1
# 2025-02-25 12:36:12   Standard: ISO 19134 Location-based services - Multimodal routing and navigation
# 2025-02-25 12:36:12   Edition: ISO 19134 Edition 1
# 2025-02-25 12:36:12   Standard: ISO 19135 Procedures for item registration
# 2025-02-25 12:36:12   Edition: ISO/CD 19135 Edition 2
# 2025-02-25 12:36:12   Edition: ISO 19135-1 Edition 1
# 2025-02-25 12:36:13   Edition: ISO 19135 Edition 1
# 2025-02-25 12:36:13   Standard: ISO 19136 Geography Markup Language (GML)
# 2025-02-25 12:36:13   Edition: ISO 19136 Edition 1
# 2025-02-25 12:36:13   Standard: ISO 19137 Core profile of the spatial schema
# 2025-02-25 12:36:13   Edition: ISO 19137 Edition 1
# 2025-02-25 12:36:13   Standard: ISO 19139 Metadata - XML schema implementation
# 2025-02-25 12:36:13   Edition: ISO 19139 Edition 1
# 2025-02-25 12:36:13   Edition: ISO 19139-2 Edition 1
# 2025-02-25 12:36:13   Standard: ISO 19141 Schema for moving features
# 2025-02-25 12:36:13   Edition: ISO 19141 Edition 1
# 2025-02-25 12:36:14   Standard: ISO 19144 Classification systems
# 2025-02-25 12:36:14   Edition: ISO TS 19144-3 Edition 1
# 2025-02-25 12:36:15   Edition: ISO/FDIS 19144-2  Edition 2
# 2025-02-25 12:36:17   Edition: ISO 19144-1 Edition 1
# 2025-02-25 12:36:17   Edition: ISO 19144-2 Edition 1
# 2025-02-25 12:36:19   Standard: ISO 19145 Registry of representations of geographic point location
# 2025-02-25 12:36:19   Edition: ISO 19145 Edition 1
# 2025-02-25 12:36:19   Standard: ISO 19146 Cross-domain vocabularies
# 2025-02-25 12:36:19   Edition: ISO 19146 Edition 2
# 2025-02-25 12:36:19   Edition: ISO 19146 Edition 1
# 2025-02-25 12:36:19   Standard: ISO 19147 Transfer Nodes
# 2025-02-25 12:36:19   Edition: ISO 19147 Edition 1
# 2025-02-25 12:36:20   Standard: ISO 19148 Linear Referencing
# 2025-02-25 12:36:20   Edition: ISO 19148 Edition 2
# 2025-02-25 12:36:20   Edition: ISO 19148 Edition 1
# 2025-02-25 12:36:20   Standard: ISO 19150 Ontology
# 2025-02-25 12:36:20   Edition: ISO 19150-4 Edition 1
# 2025-02-25 12:36:20   Edition: ISO/DIS 19150-6 Edition 1
# 2025-02-25 12:36:20   Standard: ISO 19152 Land Administration Domain Model (LADM)
# 2025-02-25 12:36:20   Edition: ISO 19152-1 Edition 1
# 2025-02-25 12:36:21   Edition: ISO/FDIS 19152-2 Edition 1
# 2025-02-25 12:36:24   Edition: ISO 19152-3 Edition 1
# 2025-02-25 12:36:24   Edition: ISO/FDIS 19152-4 Edition 1
# 2025-02-25 12:36:25   Edition: ISO/FDIS 19152-5 Edition 1
# 2025-02-25 12:36:25   Edition: ISO 19152-6 Edition 1
# 2025-02-25 12:36:25   Edition: ISO 19152 Edition 1
# 2025-02-25 12:36:31   Standard: ISO 19153 Geospatial Digital Rights Management Reference Model (GeoDRM RM)
# 2025-02-25 12:36:31   Edition: ISO 19153 Edition 1
# 2025-02-25 12:36:33   Standard: ISO 19154 Ubiquitous public access - Reference model
# 2025-02-25 12:36:33   Edition: ISO 19154 Edition 1
# 2025-02-25 12:36:33   Standard: ISO 19155 Place Identifier (PI) architecture
# 2025-02-25 12:36:33   Edition: ISO 19155 Edition 1
# 2025-02-25 12:36:33   Edition: ISO 19155-2 Edition 1
# 2025-02-25 12:36:33   Standard: ISO 19156 Observations and measurements
# 2025-02-25 12:36:33   Edition: ISO 19156 Edition 2
# 2025-02-25 12:36:33   Edition: ISO 19156 Edition 1
# 2025-02-25 12:36:34   Standard: ISO 19157 Data quality
# 2025-02-25 12:36:34   Edition: ISO 19157-1 Edition 1
# 2025-02-25 12:36:34   Edition: ISO/AWI 19157-3 Edition 1
# 2025-02-25 12:36:34   Edition: ISO 19157 Edition 1 (Amendment 1)
# 2025-02-25 12:36:34   Edition: ISO 19157 Edition 1
# 2025-02-25 12:36:35   Standard: ISO 19159 Calibration and validation of remote sensing imagery sensors and data
# 2025-02-25 12:36:35   Edition: ISO 19159-1 Edition 1
# 2025-02-25 12:36:37   Edition: ISO 19159-3 Edition 1
# 2025-02-25 12:36:37   Edition: ISO/TS 19159-4 Edition 1
# 2025-02-25 12:36:37   Standard: ISO 19160 Addressing
# 2025-02-25 12:36:37   Edition: ISO 19160-1 Edition 1
# 2025-02-25 12:36:38   Edition: ISO 19160-3 Edition 1
# 2025-02-25 12:36:38   Edition: ISO 19160-4 Edition 2
# 2025-02-25 12:36:38   Edition: ISO 19160-4 Edition 1
# 2025-02-25 12:36:39   Edition: ISO 19160-6 Edition 1
# 2025-02-25 12:36:39   Standard: ISO 19163 Content components and encoding rules for imagery and gridded data
# 2025-02-25 12:36:39   Edition: ISO 19163-2 Edition 2
# 2025-02-25 12:36:39   Edition: ISO 19163-1 Edition 1
# 2025-02-25 12:36:40   Standard: ISO 19164 Indoor feature model
# 2025-02-25 12:36:40   Edition: ISO/FDIS 19164 Edition 1
# 2025-02-25 12:36:40   Standard: ISO 19165 Preservation of digital data and metadata
# 2025-02-25 12:36:40   Edition: ISO 19165-2 Edition 1
# 2025-02-25 12:36:40   Edition: ISO 19165-1 Edition 1
# 2025-02-25 12:36:40   Standard: ISO 19166 BIM to GIS conceptual mapping (B2GM)
# 2025-02-25 12:36:40   Edition: ISO TS 19166 Edition 1
# 2025-02-25 12:36:40   Standard: ISO 19167 The Application of ubiquitous public access for air quality information
# 2025-02-25 12:36:40   Edition: ISO TR 19167 Edition 1
# 2025-02-25 12:36:41   Standard: ISO 19169 Gap-analysis GDF and ISO/TC211
# 2025-02-25 12:36:41   Edition: ISO TR 19169 Edition 1
# 2025-02-25 12:36:41   Standard: ISO 19170 Discrete global grid systems
# 2025-02-25 12:36:41   Edition: ISO 19170-1 Edition 1
# 2025-02-25 12:36:42   Standard: ISO 19174 Securing interoperability among heterogeneous city domain information models
# 2025-02-25 12:36:42   Edition: ISO/TR 19174 Edition 1
# 2025-02-25 12:36:42   Standard: ISO 19178 Training Data Markup Language for Artificial Intelligence
# 2025-02-25 12:36:42   Edition: ISO/FDIS 19178-1 Edition 1
# 2025-02-25 12:36:42   Standard: Informative
# 2025-02-25 12:36:42   Edition: Extended Metadata from 19115
# 2025-02-25 12:36:42   Edition: ISO 19160 Profiles
# 2025-02-25 12:36:42   Edition: ISO GDF
# 2025-02-25 12:36:42   Edition: Open GIS Consortium
# 2025-02-25 12:36:42   Edition: Other Location Services
# 2025-02-25 12:36:42   Edition: Spatial Examples from ISO 19107
# 2025-02-25 12:36:43   Edition: Xamples
# 2025-02-25 12:36:43   Standard: Orphans
# 2025-02-25 12:36:43   Edition: New
# 2025-02-25 12:36:43   Edition: Templates Used

# %%
def recProperties(pck,df):
    for eaEl in pck.Elements:
        # print('Element: ' + el.Name)
        if eaEl.Type.upper() in ["CLASS","INTERFACE", "DATATYPE","ENUMERATION"]:
            for eaProp in eaEl.Attributes:
                df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID,edPck.Name, eaProp.Name,'Attribute',eaProp.ClassifierID] 
            # TODO: Navigable assocation ends
             #Loop for connector dependencies
            for eaCon in eaEl.Connectors:
                if eaCon.SupplierID == eaEl.ElementID:
                    cEnd = eaCon.ClientEnd
                    ClassifierID = eaCon.ClientID 
                else:
                    cEnd = eaCon.SupplierEnd
                    ClassifierID = eaCon.SupplierID

                df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID,edPck.Name, cEnd.Role,eaCon.Type,ClassifierID] 

    for p in pck.Packages:
        recProperties(p,df)
    return df

dfProp = pd.DataFrame(columns=['ElementID','GUID','msGUID','MainStandard','edGUID', 'Edition', 'PropertyName','Type','refElementID'])
for stPck in tcMod.Packages:
    printTS('Standard: ' + stPck.Name)
    # if stPck.Elements.Count != 0:

    for edPck in stPck.Packages:
        printTS('Edition: ' + edPck.Name)
        dfProp = recProperties(edPck,dfProp)
# Out:
# 2025-02-25 12:37:10   Standard: Common types
# 2025-02-25 12:37:10   Standard: Package Context Diagrams
# 2025-02-25 12:37:10   Standard: ISO 6709 Standard representation of geographic point location by coordinates
# 2025-02-25 12:37:10   Edition: ISO 6709 Edition 2
# 2025-02-25 12:37:10   Edition: ISO 6709 Edition 1 (Corrigendum 1)
# 2025-02-25 12:37:10   Standard: ISO 19101 Reference model
# 2025-02-25 12:37:10   Edition: ISO 19101-1 Edition 1
# 2025-02-25 12:37:11   Edition: ISO 19101-2 Edition 1
# 2025-02-25 12:37:11   Edition: ISO/TS 19101-2 Edition 1
# 2025-02-25 12:37:11   Standard: ISO 19103 Conceptual schema language
# 2025-02-25 12:37:11   Edition: ISO 19103 Edition 2
# 2025-02-25 12:37:12   Edition: ISO 19103 Edition 2 Informative content
# 2025-02-25 12:37:13   Edition: ISO 19103 Edition 1
# 2025-02-25 12:37:15   Edition: ISO TS 19103 Edition 1
# 2025-02-25 12:37:16   Standard: ISO 19104 Terminology
# 2025-02-25 12:37:16   Edition: ISO 19104 Edition 1
# 2025-02-25 12:37:16   Standard: ISO 19105 Conformance and testing
# 2025-02-25 12:37:16   Edition: ISO 19105-2 Extended for normative statements
# 2025-02-25 12:37:17   Edition: ISO 19105 Edition 2
# 2025-02-25 12:37:18   Standard: ISO 19107 Spatial schema
# 2025-02-25 12:37:18   Edition: Informative Annex to Spatial Schema
# 2025-02-25 12:37:18   Edition: Possible Excess Model Elements
# 2025-02-25 12:37:18   Edition: WKT for Features and their Geometry
# 2025-02-25 12:37:18   Edition: ISO 19107 Edition 2
# 2025-02-25 12:37:22   Edition: ISO 19107 Edition 1
# 2025-02-25 12:37:25   Standard: ISO 19108 Temporal schema
# 2025-02-25 12:37:25   Edition: ISO 19108 Edition 1
# 2025-02-25 12:37:25   Standard: ISO 19109 Rules for application schema
# 2025-02-25 12:37:25   Edition: ISO/FDIS 19109 Edition 3
# 2025-02-25 12:37:26   Edition: ISO/FDIS 19109 Edition 3 Informative content
# 2025-02-25 12:37:28   Edition: ISO 19109 Edition 2
# 2025-02-25 12:37:30   Edition: ISO 19109 Edition 1
# 2025-02-25 12:37:30   Standard: ISO 19110 Methodology for feature cataloguing
# 2025-02-25 12:37:30   Edition: ISO 19110 Edition 2
# 2025-02-25 12:37:31   Edition: ISO 19110 Edition 1
# 2025-02-25 12:37:31   Standard: ISO 19111 Referencing by coordinates
# 2025-02-25 12:37:31   Edition: ISO 19111 Edition 3 (Amendment 2)
# 2025-02-25 12:37:33   Edition: ISO 19111 Edition 3 (Amendment 1)
# 2025-02-25 12:37:35   Edition: ISO 19111 Edition 3
# 2025-02-25 12:37:37   Edition: ISO 19111 Edition 2
# 2025-02-25 12:37:38   Edition: ISO 19111-2 Edition 1
# 2025-02-25 12:37:38   Standard: ISO 19112 Spatial referencing by geographic identifier
# 2025-02-25 12:37:38   Edition: ISO 19112 Edition 1
# 2025-02-25 12:37:38   Edition: ISO 19112 Edition 2
# 2025-02-25 12:37:39   Standard: ISO 19115 Metadata
# 2025-02-25 12:37:39   Edition: ISO 19115-1 Edition 1 (Complete)
# 2025-02-25 12:37:43   Edition: ISO 19115-2 Edition 2 (Complete)
# 2025-02-25 12:37:44   Edition: ISO 19115-1 Edition 1 (Amendment 2)
# 2025-02-25 12:37:44   Edition: ISO 19115-1 Edition 1
# 2025-02-25 12:37:48   Edition: ISO 19115-1 Edition 1 (Amendment 1)
# 2025-02-25 12:37:49   Edition: ISO 19115-2 Edition 2 (Amendment 1)
# 2025-02-25 12:37:49   Edition: ISO 19115-2 Edition 2
# 2025-02-25 12:37:50   Edition: ISO 19115 Edition 1 (Corrigendum 1)
# 2025-02-25 12:37:55   Edition: ISO 19115-2 Edition 1
# 2025-02-25 12:37:56   Edition: ISO 19115 Edition 1
# 2025-02-25 12:38:01   Standard: ISO 19116 Positioning services
# 2025-02-25 12:38:01   Edition: ISO/FDIS 19116 Edition 3
# 2025-02-25 12:38:02   Edition: ISO 19116 Edition 2 (Amendment 1)
# 2025-02-25 12:38:02   Edition: ISO 19116 Edition 2
# 2025-02-25 12:38:03   Edition: ISO 19116 Edition 1
# 2025-02-25 12:38:04   Standard: ISO 19117 Portrayal
# 2025-02-25 12:38:04   Edition: ISO 19117 Edition 2
# 2025-02-25 12:38:06   Edition: ISO 19117 Edition 1
# 2025-02-25 12:38:06   Standard: ISO 19118 Encoding
# 2025-02-25 12:38:06   Edition: ISO 19118 Edition 2
# 2025-02-25 12:38:06   Edition: ISO 19118 Edition 1
# 2025-02-25 12:38:07   Standard: ISO 19119 Services
# 2025-02-25 12:38:07   Edition: ISO 19119 Edition 2
# 2025-02-25 12:38:07   Edition: ISO 19119 Edition 1 (Amendment 1)
# 2025-02-25 12:38:07   Edition: ISO 19119 Edition 1
# 2025-02-25 12:38:08   Standard: ISO 19123 Schema for coverage geometry and functions
# 2025-02-25 12:38:08   Edition: ISO/DTS 19123-4 Edition 1
# 2025-02-25 12:38:08   Edition: ISO/CD 19123-2 Edition 2
# 2025-02-25 12:38:09   Edition: ISO 19123-1 Edition 1
# 2025-02-25 12:38:10   Edition: ISO 19123-2 Edition 1
# 2025-02-25 12:38:10   Edition: ISO 19123-3 Edition 1
# 2025-02-25 12:38:10   Edition: ISO 19123 Edition 1
# 2025-02-25 12:38:12   Standard: ISO 19124 Calibration and validation of remote sensing data and derived products
# 2025-02-25 12:38:12   Edition: ISO TS 19124-1 Edition 1
# 2025-02-25 12:38:13   Edition: ISO/AWI TS 19124-2 Edition 1
# 2025-02-25 12:38:13   Standard: ISO 19125 Simple feature access
# 2025-02-25 12:38:13   Edition: ISO 19125-1 Edition 2
# 2025-02-25 12:38:13   Edition: ISO 19125-1 Edition 1
# 2025-02-25 12:38:13   Standard: ISO 19126 Feature concept dictionaries and registers
# 2025-02-25 12:38:13   Edition: ISO 19126 Edition 2
# 2025-02-25 12:38:14   Edition: ISO 19126 Edition 1
# 2025-02-25 12:38:14   Standard: ISO 19128 Web map server interface
# 2025-02-25 12:38:14   Edition: ISO 19128 Edition 1
# 2025-02-25 12:38:14   Standard: ISO 19129 Imagery, gridded and coverage data framework
# 2025-02-25 12:38:14   Edition: ISO 19129 Edition 1
# 2025-02-25 12:38:15   Standard: ISO 19130 Imagery sensor models for geopositioning
# 2025-02-25 12:38:15   Edition: ISO/CD 19130-2 Edition 2
# 2025-02-25 12:38:17   Edition: ISO 19130-1 Edition 1
# 2025-02-25 12:38:18   Edition: ISO 19130 Edition 1
# 2025-02-25 12:38:20   Edition: ISO 19130-2 Edition 1
# 2025-02-25 12:38:21   Standard: ISO 19131 Data product specifications
# 2025-02-25 12:38:21   Edition: ISO 19131 Edition 2
# 2025-02-25 12:38:22   Edition: ISO 19131 Edition 1
# 2025-02-25 12:38:23   Standard: ISO 19132 Location-based services - Reference model
# 2025-02-25 12:38:23   Edition: ISO 19132 Edition 1
# 2025-02-25 12:38:24   Standard: ISO 19133 Location-based services - Tracking and navigation
# 2025-02-25 12:38:24   Edition: ISO 19133 Edition 1
# 2025-02-25 12:38:29   Standard: ISO 19134 Location-based services - Multimodal routing and navigation
# 2025-02-25 12:38:29   Edition: ISO 19134 Edition 1
# 2025-02-25 12:38:30   Standard: ISO 19135 Procedures for item registration
# 2025-02-25 12:38:30   Edition: ISO/CD 19135 Edition 2
# 2025-02-25 12:38:30   Edition: ISO 19135-1 Edition 1
# 2025-02-25 12:38:32   Edition: ISO 19135 Edition 1
# 2025-02-25 12:38:33   Standard: ISO 19136 Geography Markup Language (GML)
# 2025-02-25 12:38:33   Edition: ISO 19136 Edition 1
# 2025-02-25 12:38:35   Standard: ISO 19137 Core profile of the spatial schema
# 2025-02-25 12:38:35   Edition: ISO 19137 Edition 1
# 2025-02-25 12:38:35   Standard: ISO 19139 Metadata - XML schema implementation
# 2025-02-25 12:38:35   Edition: ISO 19139 Edition 1
# 2025-02-25 12:38:36   Edition: ISO 19139-2 Edition 1
# 2025-02-25 12:38:36   Standard: ISO 19141 Schema for moving features
# 2025-02-25 12:38:36   Edition: ISO 19141 Edition 1
# 2025-02-25 12:38:36   Standard: ISO 19144 Classification systems
# 2025-02-25 12:38:36   Edition: ISO TS 19144-3 Edition 1
# 2025-02-25 12:38:40   Edition: ISO/FDIS 19144-2  Edition 2
# 2025-02-25 12:38:44   Edition: ISO 19144-1 Edition 1
# 2025-02-25 12:38:45   Edition: ISO 19144-2 Edition 1
# 2025-02-25 12:38:49   Standard: ISO 19145 Registry of representations of geographic point location
# 2025-02-25 12:38:49   Edition: ISO 19145 Edition 1
# 2025-02-25 12:38:49   Standard: ISO 19146 Cross-domain vocabularies
# 2025-02-25 12:38:49   Edition: ISO 19146 Edition 2
# 2025-02-25 12:38:49   Edition: ISO 19146 Edition 1
# 2025-02-25 12:38:49   Standard: ISO 19147 Transfer Nodes
# 2025-02-25 12:38:49   Edition: ISO 19147 Edition 1
# 2025-02-25 12:38:52   Standard: ISO 19148 Linear Referencing
# 2025-02-25 12:38:52   Edition: ISO 19148 Edition 2
# 2025-02-25 12:38:53   Edition: ISO 19148 Edition 1
# 2025-02-25 12:38:54   Standard: ISO 19150 Ontology
# 2025-02-25 12:38:54   Edition: ISO 19150-4 Edition 1
# 2025-02-25 12:38:55   Edition: ISO/DIS 19150-6 Edition 1
# 2025-02-25 12:38:55   Standard: ISO 19152 Land Administration Domain Model (LADM)
# 2025-02-25 12:38:55   Edition: ISO 19152-1 Edition 1
# 2025-02-25 12:38:57   Edition: ISO/FDIS 19152-2 Edition 1
# 2025-02-25 12:39:07   Edition: ISO 19152-3 Edition 1
# 2025-02-25 12:39:08   Edition: ISO/FDIS 19152-4 Edition 1
# 2025-02-25 12:39:15   Edition: ISO/FDIS 19152-5 Edition 1
# 2025-02-25 12:39:17   Edition: ISO 19152-6 Edition 1
# 2025-02-25 12:39:17   Edition: ISO 19152 Edition 1
# 2025-02-25 12:39:34   Standard: ISO 19153 Geospatial Digital Rights Management Reference Model (GeoDRM RM)
# 2025-02-25 12:39:34   Edition: ISO 19153 Edition 1
# 2025-02-25 12:39:44   Standard: ISO 19154 Ubiquitous public access - Reference model
# 2025-02-25 12:39:44   Edition: ISO 19154 Edition 1
# 2025-02-25 12:39:44   Standard: ISO 19155 Place Identifier (PI) architecture
# 2025-02-25 12:39:44   Edition: ISO 19155 Edition 1
# 2025-02-25 12:39:45   Edition: ISO 19155-2 Edition 1
# 2025-02-25 12:39:45   Standard: ISO 19156 Observations and measurements
# 2025-02-25 12:39:45   Edition: ISO 19156 Edition 2
# 2025-02-25 12:39:47   Edition: ISO 19156 Edition 1
# 2025-02-25 12:39:49   Standard: ISO 19157 Data quality
# 2025-02-25 12:39:49   Edition: ISO 19157-1 Edition 1
# 2025-02-25 12:39:51   Edition: ISO/AWI 19157-3 Edition 1
# 2025-02-25 12:39:51   Edition: ISO 19157 Edition 1 (Amendment 1)
# 2025-02-25 12:39:51   Edition: ISO 19157 Edition 1
# 2025-02-25 12:39:53   Standard: ISO 19159 Calibration and validation of remote sensing imagery sensors and data
# 2025-02-25 12:39:53   Edition: ISO 19159-1 Edition 1
# 2025-02-25 12:40:05   Edition: ISO 19159-3 Edition 1
# 2025-02-25 12:40:06   Edition: ISO/TS 19159-4 Edition 1
# 2025-02-25 12:40:08   Standard: ISO 19160 Addressing
# 2025-02-25 12:40:08   Edition: ISO 19160-1 Edition 1
# 2025-02-25 12:40:10   Edition: ISO 19160-3 Edition 1
# 2025-02-25 12:40:10   Edition: ISO 19160-4 Edition 2
# 2025-02-25 12:40:12   Edition: ISO 19160-4 Edition 1
# 2025-02-25 12:40:14   Edition: ISO 19160-6 Edition 1
# 2025-02-25 12:40:14   Standard: ISO 19163 Content components and encoding rules for imagery and gridded data
# 2025-02-25 12:40:14   Edition: ISO 19163-2 Edition 2
# 2025-02-25 12:40:14   Edition: ISO 19163-1 Edition 1
# 2025-02-25 12:40:17   Standard: ISO 19164 Indoor feature model
# 2025-02-25 12:40:17   Edition: ISO/FDIS 19164 Edition 1
# 2025-02-25 12:40:18   Standard: ISO 19165 Preservation of digital data and metadata
# 2025-02-25 12:40:18   Edition: ISO 19165-2 Edition 1
# 2025-02-25 12:40:19   Edition: ISO 19165-1 Edition 1
# 2025-02-25 12:40:20   Standard: ISO 19166 BIM to GIS conceptual mapping (B2GM)
# 2025-02-25 12:40:20   Edition: ISO TS 19166 Edition 1
# 2025-02-25 12:40:21   Standard: ISO 19167 The Application of ubiquitous public access for air quality information
# 2025-02-25 12:40:21   Edition: ISO TR 19167 Edition 1
# 2025-02-25 12:40:22   Standard: ISO 19169 Gap-analysis GDF and ISO/TC211
# 2025-02-25 12:40:22   Edition: ISO TR 19169 Edition 1
# 2025-02-25 12:40:25   Standard: ISO 19170 Discrete global grid systems
# 2025-02-25 12:40:25   Edition: ISO 19170-1 Edition 1
# 2025-02-25 12:40:28   Standard: ISO 19174 Securing interoperability among heterogeneous city domain information models
# 2025-02-25 12:40:28   Edition: ISO/TR 19174 Edition 1
# 2025-02-25 12:40:28   Standard: ISO 19178 Training Data Markup Language for Artificial Intelligence
# 2025-02-25 12:40:28   Edition: ISO/FDIS 19178-1 Edition 1
# 2025-02-25 12:40:29   Standard: Informative
# 2025-02-25 12:40:29   Edition: Extended Metadata from 19115
# 2025-02-25 12:40:30   Edition: ISO 19160 Profiles
# 2025-02-25 12:40:30   Edition: ISO GDF
# 2025-02-25 12:40:31   Edition: Open GIS Consortium
# 2025-02-25 12:40:31   Edition: Other Location Services
# 2025-02-25 12:40:31   Edition: Spatial Examples from ISO 19107
# 2025-02-25 12:40:33   Edition: Xamples
# 2025-02-25 12:40:33   Standard: Orphans
# 2025-02-25 12:40:33   Edition: New
# 2025-02-25 12:40:33   Edition: Templates Used

# %%
print(dfProp.head(10))
# Out:
#    ElementID                                    GUID  \
# 0          9  {375618E4-18C3-46fb-898E-E141DA840492}
# 1          9  {375618E4-18C3-46fb-898E-E141DA840492}
# 2         11  {D532960E-61DE-4223-87BC-857100E85973}
# 3         10  {A57913B0-B61D-4de4-968A-89771001D198}
# 4         10  {A57913B0-B61D-4de4-968A-89771001D198}
# 5         10  {A57913B0-B61D-4de4-968A-89771001D198}
# 6         10  {A57913B0-B61D-4de4-968A-89771001D198}
# 7         10  {A57913B0-B61D-4de4-968A-89771001D198}
# 8         60  {1B7F996D-1F75-4924-8BBF-AEE755D776EC}
# 9         60  {1B7F996D-1F75-4924-8BBF-AEE755D776EC}
#
#                                    msGUID  \
# 0  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 1  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 2  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 3  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 4  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 5  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 6  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 7  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 8  {156E812E-1496-4aa2-8819-399111907257}
# 9  {156E812E-1496-4aa2-8819-399111907257}
#
#                                         MainStandard  \
# 0  ISO 6709 Standard representation of geographic...
# 1  ISO 6709 Standard representation of geographic...
# 2  ISO 6709 Standard representation of geographic...
# 3  ISO 6709 Standard representation of geographic...
# 4  ISO 6709 Standard representation of geographic...
# 5  ISO 6709 Standard representation of geographic...
# 6  ISO 6709 Standard representation of geographic...
# 7  ISO 6709 Standard representation of geographic...
# 8                          ISO 19101 Reference model
# 9                          ISO 19101 Reference model
#
#                                    edGUID                             Edition  \
# 0  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 1  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 2  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 3  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 4  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 5  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 6  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 7  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 8  {D9A4B755-604A-4486-AA9D-32618D2C9593}               ISO 19101-1 Edition 1
# 9  {D9A4B755-604A-4486-AA9D-32618D2C9593}               ISO 19101-1 Edition 1
#
#      PropertyName         Type  refElementID
# 0          string    Attribute           494
# 1          binary    Attribute          1494
# 2      coordTuple  Association            10
# 3           tuple    Attribute          7192
# 4        metadata  Association         31219
# 5        metadata  Association         31483
# 6                  Association            11
# 7        metadata  Association          8654
# 8  definedDataset  Association            63
# 9                  Association            62

# %% [markdown]
# # Count references
# - per element
# - per element and edition
# - per element and main standard

# %%
# Total number of references to each element

dfElCounts = dfProp.groupby(['refElementID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'TotalReferences'}, inplace=True)
# print(dfElCounts)

result_df = pd.merge(dfEl, dfElCounts, left_on='ElementID', right_on='refElementID', how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'TotalReferences':0},inplace=True)
result_df['TotalReferences'] = result_df['TotalReferences'].astype(int)
dfElStat = result_df

# Total number references to per edition package to each element
#Group by edGUID and refElement
dfElCounts = dfProp.groupby(['refElementID','edGUID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'EditionInternalReferences'}, inplace=True)
#Merge on edGUID and refElement
result_df = pd.merge(dfElStat, dfElCounts, left_on=['ElementID','edGUID'], right_on=['refElementID','edGUID'], how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'EditionInternalReferences':0},inplace=True)
result_df['EditionInternalReferences'] = result_df['EditionInternalReferences'].astype(int)
dfElStat = result_df

# Total number references to per main standards package to each element
#Group by msGUID and refElement
dfElCounts = dfProp.groupby(['refElementID','msGUID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'StandardInternalReferences'}, inplace=True)
#Merge on edGUID and refElement
result_df = pd.merge(dfElStat, dfElCounts, left_on=['ElementID','msGUID'], right_on=['refElementID','msGUID'], how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'StandardInternalReferences':0},inplace=True)
result_df['StandardInternalReferences'] = result_df['StandardInternalReferences'].astype(int)
dfElStat = result_df
dfElStat['ExternalReferences'] = dfElStat['TotalReferences'] - dfElStat['StandardInternalReferences']
# dfElStat.drop(columns=['StandardInternalReferences','EditionInternalReferences'], inplace=True)

# %%
# Statistics per element name per main standard (to summarize all references for different versions of the same element)
elStatByName = dfElStat.groupby(['msGUID', 'MainStandard','ElementName']).agg(
    VersionCount=pd.NamedAgg(column='ElementID', aggfunc='count'),
    ExternalReferences=pd.NamedAgg(column='ExternalReferences', aggfunc='sum'),
    TotalReferences=pd.NamedAgg(column='TotalReferences', aggfunc='sum')
).reset_index()

# %%
# Add referenced element name, edition etc to prop Dataframe
dfRefEls = dfElStat[['ElementID','ElementName','MainStandard','Edition']].add_prefix('ref')
dfPropWithNames = pd.merge(dfProp, dfRefEls, left_on='refElementID', right_on='refElementID', how='left')

# Add the total number of references for referenced elements
dfRefElStat= elStatByName.add_prefix('count')
dfPropWithNames = pd.merge(dfPropWithNames, dfRefElStat, left_on=['refMainStandard','refElementName'], right_on=['countMainStandard','countElementName'], how='left')
dfPropWithNames.rename(columns={'countExternalReferences': 'refExternalReferences'}, inplace=True)

#Create filtered prop DataFrame
filtered_dfPropWithNames = dfPropWithNames[(dfPropWithNames['MainStandard'] != dfPropWithNames['refMainStandard']) & (dfPropWithNames['refExternalReferences'] >= 5)]

# %% [markdown]
# # Export to Excel

# %%
file_path = mainFolder + '\\Dependencies.xlsx'
# Export to Excel 
writer = pd.ExcelWriter(file_path)
dfElStatOut = dfElStat.drop(columns=['ElementID','GUID','msGUID','edGUID'])
dfElStatOut.to_excel(writer,'Elements') 
print(f"Exported elements report to file: {file_path}") 

elStatByNameOut = elStatByName.drop(columns=['msGUID'])
elStatByNameOut.to_excel(writer,'Elements by standard') 
print(f"Exported elements report to file: {file_path}") 

print(dfPropWithNames.columns)
dfPropWithNamesOut = dfPropWithNames.drop(columns=['GUID','msGUID','edGUID'])
dfPropWithNamesOut.to_excel(writer,'Properties') 
print(f"Exported properties report to file: {file_path}") 

print(filtered_dfPropWithNames.columns)
filtered_dfPropWithNames = filtered_dfPropWithNames.drop(columns=['GUID','msGUID','edGUID'])
filtered_dfPropWithNames.to_excel(writer,'PropertiesExternal') 
print(f"Exported filtered properties report to file: {file_path}") 


writer.close()
# Out:
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_22084\3598369286.py:5: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   dfElStatOut.to_excel(writer,'Elements')
# Exported elements report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\Dependencies.xlsx
# Exported elements report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\Dependencies.xlsx
# Index(['ElementID', 'GUID', 'msGUID', 'MainStandard', 'edGUID', 'Edition',
#        'PropertyName', 'Type', 'refElementID', 'refElementName',
#        'refMainStandard', 'refEdition', 'countmsGUID', 'countMainStandard',
#        'countElementName', 'countVersionCount', 'refExternalReferences',
#        'countTotalReferences'],
#       dtype='object')
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_22084\3598369286.py:9: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   elStatByNameOut.to_excel(writer,'Elements by standard')
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_22084\3598369286.py:14: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   dfPropWithNamesOut.to_excel(writer,'Properties')
# Exported properties report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\Dependencies.xlsx
# Index(['ElementID', 'GUID', 'msGUID', 'MainStandard', 'edGUID', 'Edition',
#        'PropertyName', 'Type', 'refElementID', 'refElementName',
#        'refMainStandard', 'refEdition', 'countmsGUID', 'countMainStandard',
#        'countElementName', 'countVersionCount', 'refExternalReferences',
#        'countTotalReferences'],
#       dtype='object')
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_22084\3598369286.py:19: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   filtered_dfPropWithNames.to_excel(writer,'PropertiesExternal')
# Exported filtered properties report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\Dependencies.xlsx
