# %% [markdown]
# # ISO TC/211 Harmonised Model Dependency Controls

# %% [markdown]
# Connect to the EA app and model repository

# %%
from Parameters import *
from EAConnect import *
from HM_Controls import *
import sys
import pandas as pd

# Open EA Repository and find Model
eaApp = openEAapp()
eaRepo = openEArepo(eaApp,repo_path)
try:
    cmMod = eaRepo.Models.GetByName(modelName)
    printTS('Model "' + modelName + '" found with PackageGUID ' + cmMod.PackageGUID )
    printTS('Number of main packages: ' + str(cmMod.Packages.Count))
except Exception as e:
    printTS('Model  "' + modelName + '" not found!')
    # closeEA(eaRepo)
    # sys.exit()

timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# 2024-07-01 10:46:47   Hi EA - are you there?
# 2024-07-01 10:46:47   I am here
# 2024-07-01 10:46:47   Hi EA - Please open this repository: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\ISOTC211_HM EditorialVersion.qea
# 2024-07-01 10:46:48   OK! Repository C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\ISOTC211_HM EditorialVersion.qea is ready!
# 2024-07-01 10:46:48   Model "Conceptual Models" found with PackageGUID {7B6B28E9-C583-4363-9E9C-F37A37AE06C9}
# 2024-07-01 10:46:48   Number of main packages: 5

# %% [markdown]
# Get the TC 211 main package

# %%
tcmName = 'ISO TC211'
try:
    tcMod = cmMod.Packages.GetByName(tcmName)
    printTS('Model "' + tcmName + '" found with PackageGUID ' + tcMod.PackageGUID )
except Exception as e:
    printTS('Model  "' + tcmName + '" not found!')

printTS('Number of main packages: ' + str(tcMod.Packages.Count))
# Out:
# 2024-07-01 10:46:52   Model "ISO TC211" found with PackageGUID {CAB2E56D-50FA-4904-A16C-B34D7AE325B6}
# 2024-07-01 10:46:52   Number of main packages: 58

# %% [markdown]
#  # Create DataFrames for elements and properties
#  - Loop through the complete model:
#     - For each element: add content to rows for ElementID, GUID, main standard, standard and element name
#     - For each attribute or association end: add content to rows for elementID, GUID, main standard, standard, attribute/association name and refElementID

# %%
def recElements(pck,df):
    for eaEl in pck.Elements:
        # print('Element: ' + el.Name)
        if eaEl.Type.upper() in ["CLASS","INTERFACE", "DATATYPE","ENUMERATION"]:
           df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID, edPck.Name,eaEl.Name,eaEl.Type] 

    for p in pck.Packages:
        recElements(p,df)
    return df

dfEl = pd.DataFrame(columns=['ElementID','GUID','msGUID','MainStandard','edGUID', 'Edition', 'ElementName','Type'])
for stPck in tcMod.Packages:
    printTS('Standard: ' + stPck.Name)
    for edPck in stPck.Packages:
        printTS('Edition: ' + edPck.Name)
        dfEl = recElements(edPck,dfEl)
# Out:
# 2024-07-01 13:22:21   Standard: Common types
# 2024-07-01 13:22:21   Standard: Package Context Diagrams
# 2024-07-01 13:22:21   Standard: ISO 6709 Standard representation of geographic point location by coordinates
# 2024-07-01 13:22:21   Edition: ISO 6709 Edition 2
# 2024-07-01 13:22:21   Edition: ISO 6709 Edition 1 (Corrigendum 1)
# 2024-07-01 13:22:21   Standard: ISO 19101 Reference model
# 2024-07-01 13:22:21   Edition: ISO 19101-1 Edition 1
# 2024-07-01 13:22:21   Edition: ISO 19101-2 Edition 1
# 2024-07-01 13:22:21   Edition: ISO/TS 19101-2 Edition 1
# 2024-07-01 13:22:21   Standard: ISO 19103 Conceptual schema language
# 2024-07-01 13:22:21   Edition: ISO/FDIS 19103 Edition 2
# 2024-07-01 13:22:22   Edition: ISO/FDIS 19103 Edition 2 Informative content
# 2024-07-01 13:22:22   Edition: ISO 19103 Edition 1
# 2024-07-01 13:22:23   Edition: ISO TS 19103 Edition 1
# 2024-07-01 13:22:24   Standard: ISO 19104 Terminology
# 2024-07-01 13:22:24   Edition: ISO 19104 Edition 1
# 2024-07-01 13:22:24   Standard: ISO 19105 Conformance and testing
# 2024-07-01 13:22:24   Edition: ISO 19105-2 Extended for normative statements
# 2024-07-01 13:22:24   Edition: ISO 19105 Edition 2
# 2024-07-01 13:22:25   Standard: ISO 19107 Spatial schema
# 2024-07-01 13:22:25   Edition: Informative Annex to Spatial Schema
# 2024-07-01 13:22:25   Edition: Possible Excess Model Elements
# 2024-07-01 13:22:25   Edition: WKT for Features and their Geometry
# 2024-07-01 13:22:25   Edition: ISO 19107 Edition 2
# 2024-07-01 13:22:26   Edition: ISO 19107 Edition 1
# 2024-07-01 13:22:27   Standard: ISO 19108 Temporal schema
# 2024-07-01 13:22:27   Edition: ISO 19108 Edition 1
# 2024-07-01 13:22:27   Standard: ISO 19109 Rules for application schema
# 2024-07-01 13:22:27   Edition: ISO/DIS 19109 Edition 3
# 2024-07-01 13:22:27   Edition: ISO/DIS 19109 Edition 3 Informative content
# 2024-07-01 13:22:28   Edition: ISO 19109 Edition 2
# 2024-07-01 13:22:29   Edition: ISO 19109 Edition 1
# 2024-07-01 13:22:29   Standard: ISO 19110 Methodology for feature cataloguing
# 2024-07-01 13:22:29   Edition: ISO 19110 Edition 2
# 2024-07-01 13:22:30   Edition: ISO 19110 Edition 1
# 2024-07-01 13:22:30   Standard: ISO 19111 Referencing by coordinates
# 2024-07-01 13:22:30   Edition: ISO 19111 Edition 3 (Draft Amendment 2)
# 2024-07-01 13:22:30   Edition: ISO 19111 Edition 3 (Amendment 1)
# 2024-07-01 13:22:31   Edition: ISO 19111 Edition 3
# 2024-07-01 13:22:31   Edition: ISO 19111 Edition 2
# 2024-07-01 13:22:32   Edition: ISO 19111-2 Edition 1
# 2024-07-01 13:22:32   Standard: ISO 19112 Spatial referencing by geographic identifier
# 2024-07-01 13:22:32   Edition: ISO 19112 Edition 1
# 2024-07-01 13:22:32   Edition: ISO 19112 Edition 2
# 2024-07-01 13:22:32   Standard: ISO 19115 Metadata
# 2024-07-01 13:22:32   Edition: ISO 19115-1 Edition 1 (Complete)
# 2024-07-01 13:22:33   Edition: ISO 19115-2 Edition 2 (Complete)
# 2024-07-01 13:22:33   Edition: ISO 19115-1 Edition 1 (Amendment 2)
# 2024-07-01 13:22:33   Edition: ISO 19115-1 Edition 1
# 2024-07-01 13:22:34   Edition: ISO 19115-1 Edition 1 (Amendment 1)
# 2024-07-01 13:22:35   Edition: ISO 19115-2 Edition 2 (Amendment 1)
# 2024-07-01 13:22:35   Edition: ISO 19115-2 Edition 2
# 2024-07-01 13:22:35   Edition: ISO 19115 Edition 1 (Corrigendum 1)
# 2024-07-01 13:22:36   Edition: ISO 19115-2 Edition 1
# 2024-07-01 13:22:36   Edition: ISO 19115 Edition 1
# 2024-07-01 13:22:37   Standard: ISO 19116 Positioning services
# 2024-07-01 13:22:37   Edition: ISO/DIS 19116 Edition 3
# 2024-07-01 13:22:37   Edition: ISO 19116 Edition 2 (Amendment 1)
# 2024-07-01 13:22:38   Edition: ISO 19116 Edition 2
# 2024-07-01 13:22:38   Edition: ISO 19116 Edition 1
# 2024-07-01 13:22:38   Standard: ISO 19117 Portrayal
# 2024-07-01 13:22:38   Edition: ISO 19117 Edition 2
# 2024-07-01 13:22:39   Edition: ISO 19117 Edition 1
# 2024-07-01 13:22:39   Standard: ISO 19118 Encoding
# 2024-07-01 13:22:39   Edition: ISO 19118 Edition 2
# 2024-07-01 13:22:39   Edition: ISO 19118 Edition 1
# 2024-07-01 13:22:39   Standard: ISO 19119 Services
# 2024-07-01 13:22:39   Edition: ISO 19119 Edition 2
# 2024-07-01 13:22:39   Edition: ISO 19119 Edition 1 (Amendment 1)
# 2024-07-01 13:22:39   Edition: ISO 19119 Edition 1
# 2024-07-01 13:22:39   Standard: ISO 19123 Schema for coverage geometry and functions
# 2024-07-01 13:22:39   Edition: ISO 19123-1 Edition 1
# 2024-07-01 13:22:40   Edition: ISO 19123-2 Edition 1
# 2024-07-01 13:22:40   Edition: ISO 19123-3 Edition 1
# 2024-07-01 13:22:40   Edition: ISO 19123 Edition 1
# 2024-07-01 13:22:40   Standard: ISO 19124 Calibration and validation of remote sensing data and derived products
# 2024-07-01 13:22:40   Edition: ISO TS 19124-1 Edition 1
# 2024-07-01 13:22:41   Edition: ISO/AWI TS 19124-2 Edition 1
# 2024-07-01 13:22:41   Standard: ISO 19125 Simple feature access
# 2024-07-01 13:22:41   Edition: ISO 19125-1 Edition 2
# 2024-07-01 13:22:41   Edition: ISO 19125-1 Edition 1
# 2024-07-01 13:22:41   Standard: ISO 19126 Feature concept dictionaries and registers
# 2024-07-01 13:22:41   Edition: ISO 19126 Edition 2
# 2024-07-01 13:22:41   Edition: ISO 19126 Edition 1
# 2024-07-01 13:22:41   Standard: ISO 19128 Web map server interface
# 2024-07-01 13:22:41   Edition: ISO 19128 Edition 1
# 2024-07-01 13:22:41   Standard: ISO 19129 Imagery, gridded and coverage data framework
# 2024-07-01 13:22:41   Edition: ISO 19129 Edition 1
# 2024-07-01 13:22:41   Standard: ISO 19130 Imagery sensor models for geopositioning
# 2024-07-01 13:22:41   Edition: ISO 19130-1 Edition 1
# 2024-07-01 13:22:42   Edition: ISO 19130 Edition 1
# 2024-07-01 13:22:42   Edition: ISO 19130-2 Edition 1
# 2024-07-01 13:22:42   Standard: ISO 19131 Data product specifications
# 2024-07-01 13:22:42   Edition: ISO 19131 Edition 2
# 2024-07-01 13:22:43   Edition: ISO 19131 Edition 1
# 2024-07-01 13:22:43   Standard: ISO 19132 Location-based services - Reference model
# 2024-07-01 13:22:43   Edition: ISO 19132 Edition 1
# 2024-07-01 13:22:43   Standard: ISO 19133 Location-based services - Tracking and navigation
# 2024-07-01 13:22:43   Edition: ISO 19133 Edition 1
# 2024-07-01 13:22:44   Standard: ISO 19134 Location-based services - Multimodal routing and navigation
# 2024-07-01 13:22:44   Edition: ISO 19134 Edition 1
# 2024-07-01 13:22:44   Standard: ISO 19135 Procedures for item registration
# 2024-07-01 13:22:44   Edition: ISO/CD 19135 Edition 2
# 2024-07-01 13:22:45   Edition: ISO 19135-1 Edition 1
# 2024-07-01 13:22:45   Edition: ISO 19135 Edition 1
# 2024-07-01 13:22:45   Standard: ISO 19136 Geography Markup Language (GML)
# 2024-07-01 13:22:45   Edition: ISO 19136 Edition 1
# 2024-07-01 13:22:46   Standard: ISO 19137 Core profile of the spatial schema
# 2024-07-01 13:22:46   Edition: ISO 19137 Edition 1
# 2024-07-01 13:22:46   Standard: ISO 19139 Metadata - XML schema implementation
# 2024-07-01 13:22:46   Edition: ISO 19139 Edition 1
# 2024-07-01 13:22:46   Edition: ISO 19139-2 Edition 1
# 2024-07-01 13:22:46   Standard: ISO 19141 Schema for moving features
# 2024-07-01 13:22:46   Edition: ISO 19141 Edition 1
# 2024-07-01 13:22:46   Standard: ISO 19144 Classification systems
# 2024-07-01 13:22:46   Edition: ISO/FDIS 19144-2  Edition 2
# 2024-07-01 13:22:49   Edition: ISO DTS 19144-3 Edition 1
# 2024-07-01 13:22:50   Edition: ISO 19144-1 Edition 1
# 2024-07-01 13:22:50   Edition: ISO 19144-2 Edition 1
# 2024-07-01 13:22:52   Standard: ISO 19145 Registry of representations of geographic point location
# 2024-07-01 13:22:52   Edition: ISO 19145 Edition 1
# 2024-07-01 13:22:52   Standard: ISO 19146 Cross-domain vocabularies
# 2024-07-01 13:22:52   Edition: ISO 19146 Edition 2
# 2024-07-01 13:22:52   Edition: ISO 19146 Edition 1
# 2024-07-01 13:22:52   Standard: ISO 19147 Transfer Nodes
# 2024-07-01 13:22:52   Edition: ISO 19147 Edition 1
# 2024-07-01 13:22:53   Standard: ISO 19148 Linear Referencing
# 2024-07-01 13:22:53   Edition: ISO 19148 Edition 2
# 2024-07-01 13:22:53   Edition: ISO 19148 Edition 1
# 2024-07-01 13:22:54   Standard: ISO 19150 Ontology
# 2024-07-01 13:22:54   Edition: ISO 19150-4 Edition 1
# 2024-07-01 13:22:54   Edition: ISO/DIS 19150-6 Edition 1
# 2024-07-01 13:22:54   Standard: ISO 19152 Land Administration Domain Model (LADM)
# 2024-07-01 13:22:54   Edition: ISO/FDIS 19152-1 Edition 1
# 2024-07-01 13:22:54   Edition: ISO/DIS 19152-2 Edition 1
# 2024-07-01 13:22:56   Edition: ISO/FDIS 19152-3 Edition 1
# 2024-07-01 13:22:56   Edition: ISO/DIS 19152-4 Edition 1
# 2024-07-01 13:22:57   Edition: ISO/DIS 19152-5 Edition 1
# 2024-07-01 13:22:57   Edition: ISO 19152-6 Edition 1
# 2024-07-01 13:22:57   Edition: ISO 19152 Edition 1
# 2024-07-01 13:23:03   Standard: ISO 19153 Geospatial Digital Rights Management Reference Model (GeoDRM RM)
# 2024-07-01 13:23:03   Edition: ISO 19153 Edition 1
# 2024-07-01 13:23:06   Standard: ISO 19154 Ubiquitous public access - Reference model
# 2024-07-01 13:23:06   Edition: ISO 19154 Edition 1
# 2024-07-01 13:23:06   Standard: ISO 19155 Place Identifier (PI) architecture
# 2024-07-01 13:23:06   Edition: ISO 19155 Edition 1
# 2024-07-01 13:23:06   Edition: ISO 19155-2 Edition 1
# 2024-07-01 13:23:06   Standard: ISO 19156 Observations and measurements
# 2024-07-01 13:23:06   Edition: ISO 19156 Edition 2
# 2024-07-01 13:23:07   Edition: ISO 19156 Edition 1
# 2024-07-01 13:23:08   Standard: ISO 19157 Data quality
# 2024-07-01 13:23:08   Edition: ISO 19157-1 Edition 1
# 2024-07-01 13:23:08   Edition: ISO/AWI 19157-3 Edition 1
# 2024-07-01 13:23:08   Edition: ISO 19157 Edition 1 (Amendment 1)
# 2024-07-01 13:23:08   Edition: ISO 19157 Edition 1
# 2024-07-01 13:23:09   Standard: ISO 19159 Calibration and validation of remote sensing imagery sensors and data
# 2024-07-01 13:23:09   Edition: ISO 19159-1 Edition 1
# 2024-07-01 13:23:12   Edition: ISO 19159-3 Edition 1
# 2024-07-01 13:23:12   Edition: ISO/TS 19159-4 Edition 1
# 2024-07-01 13:23:12   Standard: ISO 19160 Addressing
# 2024-07-01 13:23:12   Edition: ISO 19160-1 Edition 1
# 2024-07-01 13:23:13   Edition: ISO 19160-3 Edition 1
# 2024-07-01 13:23:13   Edition: ISO 19160-4 Edition 2
# 2024-07-01 13:23:14   Edition: ISO 19160-4 Edition 1
# 2024-07-01 13:23:14   Edition: ISO 19160-6 Edition 1
# 2024-07-01 13:23:14   Standard: ISO 19163 Content components and encoding rules for imagery and gridded data
# 2024-07-01 13:23:14   Edition: ISO 19163-1 Edition 1
# 2024-07-01 13:23:15   Standard: ISO 19164 Indoor feature model
# 2024-07-01 13:23:15   Edition: ISO/FDIS 19164 Edition 1
# 2024-07-01 13:23:15   Standard: ISO 19165 Preservation of digital data and metadata
# 2024-07-01 13:23:15   Edition: ISO 19165-2 Edition 1
# 2024-07-01 13:23:15   Edition: ISO 19165-1 Edition 1
# 2024-07-01 13:23:16   Standard: ISO 19166 BIM to GIS conceptual mapping (B2GM)
# 2024-07-01 13:23:16   Edition: ISO TS 19166 Edition 1
# 2024-07-01 13:23:16   Standard: ISO 19167 The Application of ubiquitous public access for air quality information
# 2024-07-01 13:23:16   Edition: ISO TR 19167 Edition 1
# 2024-07-01 13:23:16   Standard: ISO 19169 Gap-analysis GDF and ISO/TC211
# 2024-07-01 13:23:16   Edition: ISO TR 19169 Edition 1
# 2024-07-01 13:23:17   Standard: ISO 19170 Discrete global grid systems
# 2024-07-01 13:23:17   Edition: ISO 19170-1 Edition 1
# 2024-07-01 13:23:18   Standard: ISO 19178 Training Data Markup Language for Artificial Intelligence
# 2024-07-01 13:23:18   Edition: ISO/AWI 19178-1 Edition 1
# 2024-07-01 13:23:18   Standard: Informative
# 2024-07-01 13:23:18   Edition: Extended Metadata from 19115
# 2024-07-01 13:23:18   Edition: ISO 19160 Profiles
# 2024-07-01 13:23:18   Edition: ISO GDF
# 2024-07-01 13:23:18   Edition: Open GIS Consortium
# 2024-07-01 13:23:18   Edition: Other Location Services
# 2024-07-01 13:23:18   Edition: Spatial Examples from ISO 19107
# 2024-07-01 13:23:19   Edition: Xamples
# 2024-07-01 13:23:19   Standard: Orphans
# 2024-07-01 13:23:19   Edition: New
# 2024-07-01 13:23:19   Edition: Templates Used

# %%
def recProperties(pck,df):
    for eaEl in pck.Elements:
        # print('Element: ' + el.Name)
        if eaEl.Type.upper() in ["CLASS","INTERFACE", "DATATYPE","ENUMERATION"]:
            for eaProp in eaEl.Attributes:
                df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID,edPck.Name, eaProp.Name,'Attribute',eaProp.ClassifierID] 
            # TODO: Navigable assocation ends
             #Loop for connector dependencies
            for eaCon in eaEl.Connectors:
                if eaCon.SupplierID == eaEl.ElementID:
                    cEnd = eaCon.ClientEnd
                    ClassifierID = eaCon.ClientID 
                else:
                    cEnd = eaCon.SupplierEnd
                    ClassifierID = eaCon.SupplierID

                df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID,edPck.Name, cEnd.Role,eaCon.Type,ClassifierID] 

    for p in pck.Packages:
        recProperties(p,df)
    return df

dfProp = pd.DataFrame(columns=['ElementID','GUID','msGUID','MainStandard','edGUID', 'Edition', 'PropertyName','Type','refElementID'])
for stPck in tcMod.Packages:
    printTS('Standard: ' + stPck.Name)
    for edPck in stPck.Packages:
        printTS('Edition: ' + edPck.Name)
        dfProp = recProperties(edPck,dfProp)
# Out:
# 2024-07-01 12:30:00   Standard: Common types
# 2024-07-01 12:30:00   Standard: Package Context Diagrams
# 2024-07-01 12:30:00   Standard: ISO 6709 Standard representation of geographic point location by coordinates
# 2024-07-01 12:30:00   Edition: ISO 6709 Edition 2
# 2024-07-01 12:30:00   Edition: ISO 6709 Edition 1 (Corrigendum 1)
# 2024-07-01 12:30:00   Standard: ISO 19101 Reference model
# 2024-07-01 12:30:00   Edition: ISO 19101-1 Edition 1
# 2024-07-01 12:30:01   Edition: ISO 19101-2 Edition 1
# 2024-07-01 12:30:01   Edition: ISO/TS 19101-2 Edition 1
# 2024-07-01 12:30:02   Standard: ISO 19103 Conceptual schema language
# 2024-07-01 12:30:02   Edition: ISO/FDIS 19103 Edition 2
# 2024-07-01 12:30:02   Edition: ISO/FDIS 19103 Edition 2 Informative content
# 2024-07-01 12:30:03   Edition: ISO 19103 Edition 1
# 2024-07-01 12:30:05   Edition: ISO TS 19103 Edition 1
# 2024-07-01 12:30:07   Standard: ISO 19104 Terminology
# 2024-07-01 12:30:07   Edition: ISO 19104 Edition 1
# 2024-07-01 12:30:07   Standard: ISO 19105 Conformance and testing
# 2024-07-01 12:30:07   Edition: ISO 19105-2 Extended for normative statements
# 2024-07-01 12:30:08   Edition: ISO 19105 Edition 2
# 2024-07-01 12:30:08   Standard: ISO 19107 Spatial schema
# 2024-07-01 12:30:08   Edition: Informative Annex to Spatial Schema
# 2024-07-01 12:30:08   Edition: Possible Excess Model Elements
# 2024-07-01 12:30:08   Edition: WKT for Features and their Geometry
# 2024-07-01 12:30:08   Edition: ISO 19107 Edition 2
# 2024-07-01 12:30:13   Edition: ISO 19107 Edition 1
# 2024-07-01 12:30:16   Standard: ISO 19108 Temporal schema
# 2024-07-01 12:30:16   Edition: ISO 19108 Edition 1
# 2024-07-01 12:30:16   Standard: ISO 19109 Rules for application schema
# 2024-07-01 12:30:16   Edition: ISO/DIS 19109 Edition 3
# 2024-07-01 12:30:17   Edition: ISO/DIS 19109 Edition 3 Informative content
# 2024-07-01 12:30:19   Edition: ISO 19109 Edition 2
# 2024-07-01 12:30:21   Edition: ISO 19109 Edition 1
# 2024-07-01 12:30:22   Standard: ISO 19110 Methodology for feature cataloguing
# 2024-07-01 12:30:22   Edition: ISO 19110 Edition 2
# 2024-07-01 12:30:22   Edition: ISO 19110 Edition 1
# 2024-07-01 12:30:23   Standard: ISO 19111 Referencing by coordinates
# 2024-07-01 12:30:23   Edition: ISO 19111 Edition 3 (Draft Amendment 2)
# 2024-07-01 12:30:25   Edition: ISO 19111 Edition 3 (Amendment 1)
# 2024-07-01 12:30:27   Edition: ISO 19111 Edition 3
# 2024-07-01 12:30:29   Edition: ISO 19111 Edition 2
# 2024-07-01 12:30:30   Edition: ISO 19111-2 Edition 1
# 2024-07-01 12:30:30   Standard: ISO 19112 Spatial referencing by geographic identifier
# 2024-07-01 12:30:30   Edition: ISO 19112 Edition 1
# 2024-07-01 12:30:31   Edition: ISO 19112 Edition 2
# 2024-07-01 12:30:31   Standard: ISO 19115 Metadata
# 2024-07-01 12:30:31   Edition: ISO 19115-1 Edition 1 (Complete)
# 2024-07-01 12:30:35   Edition: ISO 19115-2 Edition 2 (Complete)
# 2024-07-01 12:30:36   Edition: ISO 19115-1 Edition 1 (Amendment 2)
# 2024-07-01 12:30:36   Edition: ISO 19115-1 Edition 1
# 2024-07-01 12:30:41   Edition: ISO 19115-1 Edition 1 (Amendment 1)
# 2024-07-01 12:30:42   Edition: ISO 19115-2 Edition 2 (Amendment 1)
# 2024-07-01 12:30:42   Edition: ISO 19115-2 Edition 2
# 2024-07-01 12:30:43   Edition: ISO 19115 Edition 1 (Corrigendum 1)
# 2024-07-01 12:30:47   Edition: ISO 19115-2 Edition 1
# 2024-07-01 12:30:49   Edition: ISO 19115 Edition 1
# 2024-07-01 12:30:54   Standard: ISO 19116 Positioning services
# 2024-07-01 12:30:54   Edition: ISO/DIS 19116 Edition 3
# 2024-07-01 12:30:55   Edition: ISO 19116 Edition 2 (Amendment 1)
# 2024-07-01 12:30:56   Edition: ISO 19116 Edition 2
# 2024-07-01 12:30:57   Edition: ISO 19116 Edition 1
# 2024-07-01 12:30:59   Standard: ISO 19117 Portrayal
# 2024-07-01 12:30:59   Edition: ISO 19117 Edition 2
# 2024-07-01 12:31:00   Edition: ISO 19117 Edition 1
# 2024-07-01 12:31:01   Standard: ISO 19118 Encoding
# 2024-07-01 12:31:01   Edition: ISO 19118 Edition 2
# 2024-07-01 12:31:01   Edition: ISO 19118 Edition 1
# 2024-07-01 12:31:02   Standard: ISO 19119 Services
# 2024-07-01 12:31:02   Edition: ISO 19119 Edition 2
# 2024-07-01 12:31:02   Edition: ISO 19119 Edition 1 (Amendment 1)
# 2024-07-01 12:31:02   Edition: ISO 19119 Edition 1
# 2024-07-01 12:31:03   Standard: ISO 19123 Schema for coverage geometry and functions
# 2024-07-01 12:31:03   Edition: ISO 19123-1 Edition 1
# 2024-07-01 12:31:05   Edition: ISO 19123-2 Edition 1
# 2024-07-01 12:31:05   Edition: ISO 19123-3 Edition 1
# 2024-07-01 12:31:05   Edition: ISO 19123 Edition 1
# 2024-07-01 12:31:07   Standard: ISO 19124 Calibration and validation of remote sensing data and derived products
# 2024-07-01 12:31:07   Edition: ISO TS 19124-1 Edition 1
# 2024-07-01 12:31:08   Edition: ISO/AWI TS 19124-2 Edition 1
# 2024-07-01 12:31:09   Standard: ISO 19125 Simple feature access
# 2024-07-01 12:31:09   Edition: ISO 19125-1 Edition 2
# 2024-07-01 12:31:10   Edition: ISO 19125-1 Edition 1
# 2024-07-01 12:31:10   Standard: ISO 19126 Feature concept dictionaries and registers
# 2024-07-01 12:31:10   Edition: ISO 19126 Edition 2
# 2024-07-01 12:31:10   Edition: ISO 19126 Edition 1
# 2024-07-01 12:31:10   Standard: ISO 19128 Web map server interface
# 2024-07-01 12:31:10   Edition: ISO 19128 Edition 1
# 2024-07-01 12:31:11   Standard: ISO 19129 Imagery, gridded and coverage data framework
# 2024-07-01 12:31:11   Edition: ISO 19129 Edition 1
# 2024-07-01 12:31:11   Standard: ISO 19130 Imagery sensor models for geopositioning
# 2024-07-01 12:31:11   Edition: ISO 19130-1 Edition 1
# 2024-07-01 12:31:13   Edition: ISO 19130 Edition 1
# 2024-07-01 12:31:15   Edition: ISO 19130-2 Edition 1
# 2024-07-01 12:31:17   Standard: ISO 19131 Data product specifications
# 2024-07-01 12:31:17   Edition: ISO 19131 Edition 2
# 2024-07-01 12:31:19   Edition: ISO 19131 Edition 1
# 2024-07-01 12:31:20   Standard: ISO 19132 Location-based services - Reference model
# 2024-07-01 12:31:20   Edition: ISO 19132 Edition 1
# 2024-07-01 12:31:21   Standard: ISO 19133 Location-based services - Tracking and navigation
# 2024-07-01 12:31:21   Edition: ISO 19133 Edition 1
# 2024-07-01 12:31:26   Standard: ISO 19134 Location-based services - Multimodal routing and navigation
# 2024-07-01 12:31:26   Edition: ISO 19134 Edition 1
# 2024-07-01 12:31:27   Standard: ISO 19135 Procedures for item registration
# 2024-07-01 12:31:27   Edition: ISO/CD 19135 Edition 2
# 2024-07-01 12:31:28   Edition: ISO 19135-1 Edition 1
# 2024-07-01 12:31:30   Edition: ISO 19135 Edition 1
# 2024-07-01 12:31:31   Standard: ISO 19136 Geography Markup Language (GML)
# 2024-07-01 12:31:31   Edition: ISO 19136 Edition 1
# 2024-07-01 12:31:33   Standard: ISO 19137 Core profile of the spatial schema
# 2024-07-01 12:31:33   Edition: ISO 19137 Edition 1
# 2024-07-01 12:31:33   Standard: ISO 19139 Metadata - XML schema implementation
# 2024-07-01 12:31:33   Edition: ISO 19139 Edition 1
# 2024-07-01 12:31:35   Edition: ISO 19139-2 Edition 1
# 2024-07-01 12:31:35   Standard: ISO 19141 Schema for moving features
# 2024-07-01 12:31:35   Edition: ISO 19141 Edition 1
# 2024-07-01 12:31:35   Standard: ISO 19144 Classification systems
# 2024-07-01 12:31:35   Edition: ISO/FDIS 19144-2  Edition 2
# 2024-07-01 12:31:42   Edition: ISO DTS 19144-3 Edition 1
# 2024-07-01 12:31:45   Edition: ISO 19144-1 Edition 1
# 2024-07-01 12:31:46   Edition: ISO 19144-2 Edition 1
# 2024-07-01 12:31:52   Standard: ISO 19145 Registry of representations of geographic point location
# 2024-07-01 12:31:52   Edition: ISO 19145 Edition 1
# 2024-07-01 12:31:52   Standard: ISO 19146 Cross-domain vocabularies
# 2024-07-01 12:31:52   Edition: ISO 19146 Edition 2
# 2024-07-01 12:31:52   Edition: ISO 19146 Edition 1
# 2024-07-01 12:31:53   Standard: ISO 19147 Transfer Nodes
# 2024-07-01 12:31:53   Edition: ISO 19147 Edition 1
# 2024-07-01 12:31:55   Standard: ISO 19148 Linear Referencing
# 2024-07-01 12:31:55   Edition: ISO 19148 Edition 2
# 2024-07-01 12:31:57   Edition: ISO 19148 Edition 1
# 2024-07-01 12:31:58   Standard: ISO 19150 Ontology
# 2024-07-01 12:31:58   Edition: ISO 19150-4 Edition 1
# 2024-07-01 12:31:59   Edition: ISO/DIS 19150-6 Edition 1
# 2024-07-01 12:31:59   Standard: ISO 19152 Land Administration Domain Model (LADM)
# 2024-07-01 12:31:59   Edition: ISO/FDIS 19152-1 Edition 1
# 2024-07-01 12:32:01   Edition: ISO/DIS 19152-2 Edition 1
# 2024-07-01 12:32:06   Edition: ISO/FDIS 19152-3 Edition 1
# 2024-07-01 12:32:08   Edition: ISO/DIS 19152-4 Edition 1
# 2024-07-01 12:32:11   Edition: ISO/DIS 19152-5 Edition 1
# 2024-07-01 12:32:12   Edition: ISO 19152-6 Edition 1
# 2024-07-01 12:32:12   Edition: ISO 19152 Edition 1
# 2024-07-01 12:32:30   Standard: ISO 19153 Geospatial Digital Rights Management Reference Model (GeoDRM RM)
# 2024-07-01 12:32:30   Edition: ISO 19153 Edition 1
# 2024-07-01 12:32:40   Standard: ISO 19154 Ubiquitous public access - Reference model
# 2024-07-01 12:32:40   Edition: ISO 19154 Edition 1
# 2024-07-01 12:32:40   Standard: ISO 19155 Place Identifier (PI) architecture
# 2024-07-01 12:32:40   Edition: ISO 19155 Edition 1
# 2024-07-01 12:32:41   Edition: ISO 19155-2 Edition 1
# 2024-07-01 12:32:41   Standard: ISO 19156 Observations and measurements
# 2024-07-01 12:32:41   Edition: ISO 19156 Edition 2
# 2024-07-01 12:32:43   Edition: ISO 19156 Edition 1
# 2024-07-01 12:32:45   Standard: ISO 19157 Data quality
# 2024-07-01 12:32:45   Edition: ISO 19157-1 Edition 1
# 2024-07-01 12:32:47   Edition: ISO/AWI 19157-3 Edition 1
# 2024-07-01 12:32:47   Edition: ISO 19157 Edition 1 (Amendment 1)
# 2024-07-01 12:32:47   Edition: ISO 19157 Edition 1
# 2024-07-01 12:32:49   Standard: ISO 19159 Calibration and validation of remote sensing imagery sensors and data
# 2024-07-01 12:32:49   Edition: ISO 19159-1 Edition 1
# 2024-07-01 12:33:02   Edition: ISO 19159-3 Edition 1
# 2024-07-01 12:33:04   Edition: ISO/TS 19159-4 Edition 1
# 2024-07-01 12:33:05   Standard: ISO 19160 Addressing
# 2024-07-01 12:33:05   Edition: ISO 19160-1 Edition 1
# 2024-07-01 12:33:08   Edition: ISO 19160-3 Edition 1
# 2024-07-01 12:33:08   Edition: ISO 19160-4 Edition 2
# 2024-07-01 12:33:10   Edition: ISO 19160-4 Edition 1
# 2024-07-01 12:33:12   Edition: ISO 19160-6 Edition 1
# 2024-07-01 12:33:12   Standard: ISO 19163 Content components and encoding rules for imagery and gridded data
# 2024-07-01 12:33:12   Edition: ISO 19163-1 Edition 1
# 2024-07-01 12:33:15   Standard: ISO 19164 Indoor feature model
# 2024-07-01 12:33:15   Edition: ISO/FDIS 19164 Edition 1
# 2024-07-01 12:33:17   Standard: ISO 19165 Preservation of digital data and metadata
# 2024-07-01 12:33:17   Edition: ISO 19165-2 Edition 1
# 2024-07-01 12:33:17   Edition: ISO 19165-1 Edition 1
# 2024-07-01 12:33:18   Standard: ISO 19166 BIM to GIS conceptual mapping (B2GM)
# 2024-07-01 12:33:18   Edition: ISO TS 19166 Edition 1
# 2024-07-01 12:33:19   Standard: ISO 19167 The Application of ubiquitous public access for air quality information
# 2024-07-01 12:33:19   Edition: ISO TR 19167 Edition 1
# 2024-07-01 12:33:20   Standard: ISO 19169 Gap-analysis GDF and ISO/TC211
# 2024-07-01 12:33:20   Edition: ISO TR 19169 Edition 1
# 2024-07-01 12:33:24   Standard: ISO 19170 Discrete global grid systems
# 2024-07-01 12:33:24   Edition: ISO 19170-1 Edition 1
# 2024-07-01 12:33:27   Standard: ISO 19178 Training Data Markup Language for Artificial Intelligence
# 2024-07-01 12:33:27   Edition: ISO/AWI 19178-1 Edition 1
# 2024-07-01 12:33:28   Standard: Informative
# 2024-07-01 12:33:28   Edition: Extended Metadata from 19115
# 2024-07-01 12:33:28   Edition: ISO 19160 Profiles
# 2024-07-01 12:33:28   Edition: ISO GDF
# 2024-07-01 12:33:29   Edition: Open GIS Consortium
# 2024-07-01 12:33:29   Edition: Other Location Services
# 2024-07-01 12:33:30   Edition: Spatial Examples from ISO 19107
# 2024-07-01 12:33:31   Edition: Xamples
# 2024-07-01 12:33:32   Standard: Orphans
# 2024-07-01 12:33:32   Edition: New
# 2024-07-01 12:33:32   Edition: Templates Used

# %%
print(dfProp.head(10))
# Out:
#    ElementID                                    GUID  \
# 0          9  {375618E4-18C3-46fb-898E-E141DA840492}
# 1          9  {375618E4-18C3-46fb-898E-E141DA840492}
# 2         10  {A57913B0-B61D-4de4-968A-89771001D198}
# 3        118  {26610375-01C5-44f1-9B56-2A25049AEDEA}
# 4        118  {26610375-01C5-44f1-9B56-2A25049AEDEA}
# 5        116  {2541775F-9070-49de-AB98-28F0329A8C6D}
# 6        119  {4A7D91D7-6A2E-4e73-9BE8-9C6691F27D0E}
# 7        121  {D7271D77-49A8-43b2-A5BE-1F731A217309}
# 8        124  {3F935969-2134-4f0a-8ADA-38DF62AD1D18}
# 9        124  {3F935969-2134-4f0a-8ADA-38DF62AD1D18}
#
#                                    msGUID  \
# 0  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 1  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 2  {44346D64-FF7D-40bb-B945-570B5E243B5C}
# 3  {156E812E-1496-4aa2-8819-399111907257}
# 4  {156E812E-1496-4aa2-8819-399111907257}
# 5  {156E812E-1496-4aa2-8819-399111907257}
# 6  {156E812E-1496-4aa2-8819-399111907257}
# 7  {156E812E-1496-4aa2-8819-399111907257}
# 8  {156E812E-1496-4aa2-8819-399111907257}
# 9  {156E812E-1496-4aa2-8819-399111907257}
#
#                                         MainStandard  \
# 0  ISO 6709 Standard representation of geographic...
# 1  ISO 6709 Standard representation of geographic...
# 2  ISO 6709 Standard representation of geographic...
# 3                          ISO 19101 Reference model
# 4                          ISO 19101 Reference model
# 5                          ISO 19101 Reference model
# 6                          ISO 19101 Reference model
# 7                          ISO 19101 Reference model
# 8                          ISO 19101 Reference model
# 9                          ISO 19101 Reference model
#
#                                    edGUID                             Edition  \
# 0  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 1  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 2  {F70D39CC-68AD-47bd-BDA8-FCEE3CDFF824}  ISO 6709 Edition 1 (Corrigendum 1)
# 3  {ABD616CB-ADAA-4a24-9226-EF0B6F6C8127}               ISO 19101-2 Edition 1
# 4  {ABD616CB-ADAA-4a24-9226-EF0B6F6C8127}               ISO 19101-2 Edition 1
# 5  {ABD616CB-ADAA-4a24-9226-EF0B6F6C8127}               ISO 19101-2 Edition 1
# 6  {ABD616CB-ADAA-4a24-9226-EF0B6F6C8127}               ISO 19101-2 Edition 1
# 7  {ABD616CB-ADAA-4a24-9226-EF0B6F6C8127}               ISO 19101-2 Edition 1
# 8  {ABD616CB-ADAA-4a24-9226-EF0B6F6C8127}               ISO 19101-2 Edition 1
# 9  {ABD616CB-ADAA-4a24-9226-EF0B6F6C8127}               ISO 19101-2 Edition 1
#
#   PropertyName       Type  refElementID
# 0       string  Attribute           494
# 1       binary  Attribute          1494
# 2        tuple  Attribute          7192
# 3         unit  Attribute           494
# 4     dataType  Attribute           257
# 5         name  Attribute           494
# 6       values  Attribute           116
# 7     dataType  Attribute           491
# 8    featureID  Attribute           491
# 9  featureType  Attribute           462

# %% [markdown]
# # Count references
# - per element
# - per element and edition
# - per element and main standard

# %%
# Total number of references to each element

dfElCounts = dfProp.groupby(['refElementID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'TotalReferences'}, inplace=True)
# print(dfElCounts)

result_df = pd.merge(dfEl, dfElCounts, left_on='ElementID', right_on='refElementID', how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'TotalReferences':0},inplace=True)
result_df['TotalReferences'] = result_df['TotalReferences'].astype(int)
dfElStat = result_df

# Total number references to per edition package to each element
#Group by edGUID and refElement
dfElCounts = dfProp.groupby(['refElementID','edGUID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'EditionInternalReferences'}, inplace=True)
#Merge on edGUID and refElement
result_df = pd.merge(dfElStat, dfElCounts, left_on=['ElementID','edGUID'], right_on=['refElementID','edGUID'], how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'EditionInternalReferences':0},inplace=True)
result_df['EditionInternalReferences'] = result_df['EditionInternalReferences'].astype(int)
dfElStat = result_df

# Total number references to per main standards package to each element
#Group by msGUID and refElement
dfElCounts = dfProp.groupby(['refElementID','msGUID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'StandardInternalReferences'}, inplace=True)
#Merge on edGUID and refElement
result_df = pd.merge(dfElStat, dfElCounts, left_on=['ElementID','msGUID'], right_on=['refElementID','msGUID'], how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'StandardInternalReferences':0},inplace=True)
result_df['StandardInternalReferences'] = result_df['StandardInternalReferences'].astype(int)
dfElStat = result_df
dfElStat['ExternalReferences'] = dfElStat['TotalReferences'] - dfElStat['StandardInternalReferences']
# dfElStat.drop(columns=['StandardInternalReferences','EditionInternalReferences'], inplace=True)

# %%
# Statistics per element name per main standard (to summarize all references for different versions of the same element)
elStatByName = dfElStat.groupby(['msGUID', 'MainStandard','ElementName']).agg(
    VersionCount=pd.NamedAgg(column='ElementID', aggfunc='count'),
    ExternalReferences=pd.NamedAgg(column='ExternalReferences', aggfunc='sum'),
    TotalReferences=pd.NamedAgg(column='TotalReferences', aggfunc='sum')
).reset_index()

# %% [markdown]
# # Export to Excel

# %%
print('')
file_path = mainFolder + '\\Dependencies.xlsx'
# Export to Excel 
writer = pd.ExcelWriter(file_path)
dfElStat.to_excel(writer,'Elements') 
print(f"Exported elements report to file: {file_path}") 

elStatByName.to_excel(writer,'Elements by standard') 
print(f"Exported elements report to file: {file_path}") 

dfProp.to_excel(writer,'Properties') 
print(f"Exported properties report to file: {file_path}") 

writer.close()
# Out:
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_17708\2208172230.py:5: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   dfElStat.to_excel(writer,'Elements')
# Exported elements report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\Dependencies.xlsx
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_17708\2208172230.py:8: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   elStatByName.to_excel(writer,'Elements by standard')
# Exported elements report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\Dependencies.xlsx
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_17708\2208172230.py:11: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   dfProp.to_excel(writer,'Properties')
# Exported properties report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\Dependencies.xlsx

# %%
# List properties refering to a specific element
