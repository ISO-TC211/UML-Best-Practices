# %% [markdown]
# # ISO TC/211 Harmonised Model Dependency Controls

# %% [markdown]
# Connect to the EA app and model repository

# %%
from Parameters import *
from EAConnect import *
from HM_Controls import *
import sys
import pandas as pd

# Open EA Repository and find Model
eaApp = openEAapp()
eaRepo = openEArepo(eaApp,repo_path)
try:
    cmMod = eaRepo.Models.GetByName(modelName)
    printTS('Model "' + modelName + '" found with PackageGUID ' + cmMod.PackageGUID )
    printTS('Number of main packages: ' + str(cmMod.Packages.Count))
except Exception as e:
    printTS('Model  "' + modelName + '" not found!')
    # closeEA(eaRepo)
    # sys.exit()

timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# 2025-04-11 09:04:06   Hi EA - are you there?
# 2025-04-11 09:04:06   I am here
# 2025-04-11 09:04:06   Hi EA - Please open this repository: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\ISOTC211_HM EditorialVersion.qea
# 2025-04-11 09:04:07   OK! Repository C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\ISOTC211_HM EditorialVersion.qea is ready!
# 2025-04-11 09:04:07   Model "Conceptual Models" found with PackageGUID {7B6B28E9-C583-4363-9E9C-F37A37AE06C9}
# 2025-04-11 09:04:07   Number of main packages: 5

# %% [markdown]
# Get the TC 211 main package

# %%
tcmName = 'ISO TC211'
try:
    tcMod = cmMod.Packages.GetByName(tcmName)
    printTS('Model "' + tcmName + '" found with PackageGUID ' + tcMod.PackageGUID )
except Exception as e:
    printTS('Model  "' + tcmName + '" not found!')

printTS('Number of main packages: ' + str(tcMod.Packages.Count))
# Out:
# 2025-04-11 09:04:09   Model "ISO TC211" found with PackageGUID {CAB2E56D-50FA-4904-A16C-B34D7AE325B6}
# 2025-04-11 09:04:09   Number of main packages: 59

# %% [markdown]
#  # Create DataFrame for elements
#  - Loop through the complete model:
#     - For each element: add content to rows for ElementID, GUID, main standard, standard and element name

# %%
# This script lists all elements (classifiers) in the whole HM

def recElements(pck,df):
    for eaEl in pck.Elements:
        # print('Element: ' + el.Name)
        if eaEl.Type.upper() in ["CLASS","INTERFACE", "DATATYPE","ENUMERATION"]:
           df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID, edPck.Name,eaEl.Name,eaEl.Type] 

    for p in pck.Packages:
        recElements(p,df)
    return df

dfEl = pd.DataFrame(columns=['ElementID','GUID','msGUID','MainStandard','edGUID', 'Edition', 'ElementName','Type'])
# 'ElementID' = Internal ElementID for the classifier
# 'GUID' = GUID for the classifiser
# 'msGUID' = GUID for the main standard (e.g. GUID for the package ISO 19115 Metadata)
# 'MainStandard' = Name of the main standard
# 'edGUID' = GUID for the edition package (e.g. the GUID for the package ISO 19115-1 Edition 1 (Amendment 1))
# 'Edition' = Name of the edition
# 'ElementName' = Name of the classifier
# 'Type' = Classifier type (Class, Interface etc)

for stPck in tcMod.Packages:
    printTS('Standard: ' + stPck.Name)
    if stPck.Elements.Count > 0:
        edPck = stPck
        printTS('Edition: ' + edPck.Name)
        dfEl = recElements(edPck,dfEl)        
    for edPck in stPck.Packages:
        printTS('Edition: ' + edPck.Name)
        dfEl = recElements(edPck,dfEl)
# Out:
# 2025-04-11 09:04:13   Standard: Common types
# 2025-04-11 09:04:13   Standard: Package Context Diagrams
# 2025-04-11 09:04:13   Standard: ISO 6709 Standard representation of geographic point location by coordinates
# 2025-04-11 09:04:13   Edition: ISO 6709 Edition 2
# 2025-04-11 09:04:13   Edition: ISO 6709 Edition 1 (Corrigendum 1)
# 2025-04-11 09:04:13   Standard: ISO 19101 Reference model
# 2025-04-11 09:04:13   Edition: ISO 19101-1 Edition 1
# 2025-04-11 09:04:14   Edition: ISO 19101-2 Edition 1
# 2025-04-11 09:04:14   Edition: ISO/TS 19101-2 Edition 1
# 2025-04-11 09:04:14   Standard: ISO 19103 Conceptual schema language
# 2025-04-11 09:04:14   Edition: ISO 19103 Edition 2
# 2025-04-11 09:04:14   Edition: ISO 19103 Edition 2 Informative content
# 2025-04-11 09:04:15   Edition: ISO 19103 Edition 1
# 2025-04-11 09:04:15   Edition: ISO TS 19103 Edition 1
# 2025-04-11 09:04:16   Standard: ISO 19104 Terminology
# 2025-04-11 09:04:16   Edition: ISO 19104 Edition 1
# 2025-04-11 09:04:16   Standard: ISO 19105 Conformance and testing
# 2025-04-11 09:04:16   Edition: ISO 19105-2 Extended for normative statements
# 2025-04-11 09:04:16   Edition: ISO 19105 Edition 2
# 2025-04-11 09:04:16   Standard: ISO 19107 Spatial schema
# 2025-04-11 09:04:16   Edition: Informative Annex to Spatial Schema
# 2025-04-11 09:04:16   Edition: Possible Excess Model Elements
# 2025-04-11 09:04:16   Edition: WKT for Features and their Geometry
# 2025-04-11 09:04:16   Edition: ISO 19107 Edition 2
# 2025-04-11 09:04:17   Edition: ISO 19107 Edition 1
# 2025-04-11 09:04:18   Standard: ISO 19108 Temporal schema
# 2025-04-11 09:04:18   Edition: ISO 19108 Edition 1
# 2025-04-11 09:04:18   Standard: ISO 19109 Rules for application schema
# 2025-04-11 09:04:18   Edition: ISO/FDIS 19109 Edition 3
# 2025-04-11 09:04:18   Edition: ISO/FDIS 19109 Edition 3 Informative content
# 2025-04-11 09:04:19   Edition: ISO 19109 Edition 2
# 2025-04-11 09:04:20   Edition: ISO 19109 Edition 1
# 2025-04-11 09:04:20   Standard: ISO 19110 Methodology for feature cataloguing
# 2025-04-11 09:04:20   Edition: ISO 19110 Edition 2
# 2025-04-11 09:04:20   Edition: ISO 19110 Edition 1
# 2025-04-11 09:04:20   Standard: ISO 19111 Referencing by coordinates
# 2025-04-11 09:04:20   Edition: ISO 19111 Edition 3 (Amendment 2)
# 2025-04-11 09:04:20   Edition: ISO 19111 Edition 3 (Amendment 1)
# 2025-04-11 09:04:21   Edition: ISO 19111 Edition 3
# 2025-04-11 09:04:21   Edition: ISO 19111 Edition 2
# 2025-04-11 09:04:21   Edition: ISO 19111-2 Edition 1
# 2025-04-11 09:04:21   Standard: ISO 19112 Spatial referencing by geographic identifier
# 2025-04-11 09:04:21   Edition: ISO 19112 Edition 1
# 2025-04-11 09:04:21   Edition: ISO 19112 Edition 2
# 2025-04-11 09:04:21   Standard: ISO 19115 Metadata
# 2025-04-11 09:04:21   Edition: ISO/AWI 19115-1 Edition 2
# 2025-04-11 09:04:22   Edition: ISO 19115-1 Edition 1 (Complete)
# 2025-04-11 09:04:23   Edition: ISO 19115-2 Edition 2 (Complete)
# 2025-04-11 09:04:23   Edition: ISO 19115-1 Edition 1 (Amendment 2)
# 2025-04-11 09:04:23   Edition: ISO 19115-1 Edition 1
# 2025-04-11 09:04:24   Edition: ISO 19115-1 Edition 1 (Amendment 1)
# 2025-04-11 09:04:24   Edition: ISO 19115-2 Edition 2 (Amendment 1)
# 2025-04-11 09:04:24   Edition: ISO 19115-2 Edition 2
# 2025-04-11 09:04:24   Edition: ISO 19115-2 Edition 1
# 2025-04-11 09:04:24   Edition: ISO 19115 Edition 1 (Corrigendum 1)
# 2025-04-11 09:04:25   Edition: ISO 19115 Edition 1
# 2025-04-11 09:04:26   Standard: ISO 19116 Positioning services
# 2025-04-11 09:04:26   Edition: ISO/FDIS 19116 Edition 3
# 2025-04-11 09:04:26   Edition: ISO 19116 Edition 2 (Amendment 1)
# 2025-04-11 09:04:26   Edition: ISO 19116 Edition 2
# 2025-04-11 09:04:26   Edition: ISO 19116 Edition 1
# 2025-04-11 09:04:26   Standard: ISO 19117 Portrayal
# 2025-04-11 09:04:26   Edition: ISO 19117 Edition 2
# 2025-04-11 09:04:27   Edition: ISO 19117 Edition 1
# 2025-04-11 09:04:27   Standard: ISO 19118 Encoding
# 2025-04-11 09:04:27   Edition: ISO 19118 Edition 2
# 2025-04-11 09:04:27   Edition: ISO 19118 Edition 1
# 2025-04-11 09:04:27   Standard: ISO 19119 Services
# 2025-04-11 09:04:27   Edition: ISO 19119 Edition 2
# 2025-04-11 09:04:27   Edition: ISO 19119 Edition 1 (Amendment 1)
# 2025-04-11 09:04:27   Edition: ISO 19119 Edition 1
# 2025-04-11 09:04:27   Standard: ISO 19123 Schema for coverage geometry and functions
# 2025-04-11 09:04:27   Edition: ISO/DTS 19123-4 Edition 1
# 2025-04-11 09:04:27   Edition: ISO/CD 19123-2 Edition 2
# 2025-04-11 09:04:28   Edition: ISO 19123-1 Edition 1
# 2025-04-11 09:04:28   Edition: ISO 19123-2 Edition 1
# 2025-04-11 09:04:28   Edition: ISO 19123-3 Edition 1
# 2025-04-11 09:04:28   Edition: ISO 19123 Edition 1
# 2025-04-11 09:04:28   Standard: ISO 19124 Calibration and validation of remote sensing data and derived products
# 2025-04-11 09:04:28   Edition: ISO/DTS 19124-2 Edition 1
# 2025-04-11 09:04:28   Edition: ISO TS 19124-1 Edition 1
# 2025-04-11 09:04:29   Standard: ISO 19125 Simple feature access
# 2025-04-11 09:04:29   Edition: ISO 19125-1 Edition 2
# 2025-04-11 09:04:29   Edition: ISO 19125-1 Edition 1
# 2025-04-11 09:04:29   Standard: ISO 19126 Feature concept dictionaries and registers
# 2025-04-11 09:04:29   Edition: ISO 19126 Edition 2
# 2025-04-11 09:04:29   Edition: ISO 19126 Edition 1
# 2025-04-11 09:04:29   Standard: ISO 19128 Web map server interface
# 2025-04-11 09:04:29   Edition: ISO 19128 Edition 1
# 2025-04-11 09:04:29   Standard: ISO 19129 Imagery, gridded and coverage data framework
# 2025-04-11 09:04:29   Edition: ISO 19129 Edition 1
# 2025-04-11 09:04:29   Standard: ISO 19130 Imagery sensor models for geopositioning
# 2025-04-11 09:04:29   Edition: ISO/CD 19130-2 Edition 2
# 2025-04-11 09:04:29   Edition: ISO 19130-1 Edition 1
# 2025-04-11 09:04:29   Edition: ISO 19130 Edition 1
# 2025-04-11 09:04:30   Edition: ISO 19130-2 Edition 1
# 2025-04-11 09:04:30   Standard: ISO 19131 Data product specifications
# 2025-04-11 09:04:30   Edition: ISO 19131 Edition 2
# 2025-04-11 09:04:30   Edition: ISO 19131 Edition 1
# 2025-04-11 09:04:30   Standard: ISO 19132 Location-based services - Reference model
# 2025-04-11 09:04:30   Edition: ISO 19132 Edition 1
# 2025-04-11 09:04:31   Standard: ISO 19133 Location-based services - Tracking and navigation
# 2025-04-11 09:04:31   Edition: ISO 19133 Edition 1
# 2025-04-11 09:04:31   Standard: ISO 19134 Location-based services - Multimodal routing and navigation
# 2025-04-11 09:04:31   Edition: ISO 19134 Edition 1
# 2025-04-11 09:04:32   Standard: ISO 19135 Procedures for item registration
# 2025-04-11 09:04:32   Edition: ISO/CD 19135 Edition 2
# 2025-04-11 09:04:32   Edition: ISO 19135-1 Edition 1
# 2025-04-11 09:04:32   Edition: ISO 19135 Edition 1
# 2025-04-11 09:04:32   Standard: ISO 19136 Geography Markup Language (GML)
# 2025-04-11 09:04:32   Edition: ISO 19136 Edition 1
# 2025-04-11 09:04:33   Standard: ISO 19137 Core profile of the spatial schema
# 2025-04-11 09:04:33   Edition: ISO 19137 Edition 1
# 2025-04-11 09:04:33   Standard: ISO 19139 Metadata - XML schema implementation
# 2025-04-11 09:04:33   Edition: ISO 19139 Edition 1
# 2025-04-11 09:04:33   Edition: ISO 19139-2 Edition 1
# 2025-04-11 09:04:33   Standard: ISO 19141 Schema for moving features
# 2025-04-11 09:04:33   Edition: ISO 19141 Edition 1
# 2025-04-11 09:04:33   Standard: ISO 19144 Classification systems
# 2025-04-11 09:04:33   Edition: ISO TS 19144-3 Edition 1
# 2025-04-11 09:04:35   Edition: ISO/FDIS 19144-2  Edition 2
# 2025-04-11 09:04:37   Edition: ISO 19144-1 Edition 1
# 2025-04-11 09:04:37   Edition: ISO 19144-2 Edition 1
# 2025-04-11 09:04:39   Standard: ISO 19145 Registry of representations of geographic point location
# 2025-04-11 09:04:39   Edition: ISO 19145 Edition 1
# 2025-04-11 09:04:39   Standard: ISO 19146 Cross-domain vocabularies
# 2025-04-11 09:04:39   Edition: ISO 19146 Edition 2
# 2025-04-11 09:04:39   Edition: ISO 19146 Edition 1
# 2025-04-11 09:04:39   Standard: ISO 19147 Transfer Nodes
# 2025-04-11 09:04:39   Edition: ISO 19147 Edition 1
# 2025-04-11 09:04:40   Standard: ISO 19148 Linear Referencing
# 2025-04-11 09:04:40   Edition: ISO 19148 Edition 2
# 2025-04-11 09:04:40   Edition: ISO 19148 Edition 1
# 2025-04-11 09:04:40   Standard: ISO 19150 Ontology
# 2025-04-11 09:04:40   Edition: ISO 19150-4 Edition 1
# 2025-04-11 09:04:41   Edition: ISO/DIS 19150-6 Edition 1
# 2025-04-11 09:04:41   Standard: ISO 19152 Land Administration Domain Model (LADM)
# 2025-04-11 09:04:41   Edition: ISO 19152-1 Edition 1
# 2025-04-11 09:04:41   Edition: ISO/FDIS 19152-2 Edition 1
# 2025-04-11 09:04:45   Edition: ISO 19152-3 Edition 1
# 2025-04-11 09:04:45   Edition: ISO/FDIS 19152-4 Edition 1
# 2025-04-11 09:04:47   Edition: ISO/FDIS 19152-5 Edition 1
# 2025-04-11 09:04:47   Edition: ISO 19152-6 Edition 1
# 2025-04-11 09:04:47   Edition: ISO 19152 Edition 1
# 2025-04-11 09:04:55   Standard: ISO 19153 Geospatial Digital Rights Management Reference Model (GeoDRM RM)
# 2025-04-11 09:04:55   Edition: ISO 19153 Edition 1
# 2025-04-11 09:04:57   Standard: ISO 19154 Ubiquitous public access - Reference model
# 2025-04-11 09:04:57   Edition: ISO 19154 Edition 1
# 2025-04-11 09:04:57   Standard: ISO 19155 Place Identifier (PI) architecture
# 2025-04-11 09:04:57   Edition: ISO 19155 Edition 1
# 2025-04-11 09:04:57   Edition: ISO 19155-2 Edition 1
# 2025-04-11 09:04:57   Standard: ISO 19156 Observations and measurements
# 2025-04-11 09:04:57   Edition: ISO 19156 Edition 2
# 2025-04-11 09:04:58   Edition: ISO 19156 Edition 1
# 2025-04-11 09:04:59   Standard: ISO 19157 Data quality
# 2025-04-11 09:04:59   Edition: ISO 19157-1 Edition 1
# 2025-04-11 09:04:59   Edition: ISO/DIS 19157-3 Edition 1
# 2025-04-11 09:04:59   Edition: ISO 19157 Edition 1 (Amendment 1)
# 2025-04-11 09:04:59   Edition: ISO 19157 Edition 1
# 2025-04-11 09:05:00   Standard: ISO 19159 Calibration and validation of remote sensing imagery sensors and data
# 2025-04-11 09:05:00   Edition: ISO 19159-1 Edition 1
# 2025-04-11 09:05:02   Edition: ISO 19159-3 Edition 1
# 2025-04-11 09:05:03   Edition: ISO/TS 19159-4 Edition 1
# 2025-04-11 09:05:03   Standard: ISO 19160 Addressing
# 2025-04-11 09:05:03   Edition: ISO 19160-1 Edition 1
# 2025-04-11 09:05:04   Edition: ISO 19160-3 Edition 1
# 2025-04-11 09:05:04   Edition: ISO 19160-4 Edition 2
# 2025-04-11 09:05:04   Edition: ISO 19160-4 Edition 1
# 2025-04-11 09:05:05   Edition: ISO 19160-6 Edition 1
# 2025-04-11 09:05:05   Standard: ISO 19163 Content components and encoding rules for imagery and gridded data
# 2025-04-11 09:05:05   Edition: ISO 19163-2 Edition 2
# 2025-04-11 09:05:05   Edition: ISO 19163-1 Edition 1
# 2025-04-11 09:05:06   Standard: ISO 19164 Indoor feature model
# 2025-04-11 09:05:06   Edition: ISO/FDIS 19164 Edition 1
# 2025-04-11 09:05:06   Standard: ISO 19165 Preservation of digital data and metadata
# 2025-04-11 09:05:06   Edition: ISO 19165-2 Edition 1
# 2025-04-11 09:05:06   Edition: ISO 19165-1 Edition 1
# 2025-04-11 09:05:06   Standard: ISO 19166 BIM to GIS conceptual mapping (B2GM)
# 2025-04-11 09:05:06   Edition: ISO/CD TS 19166 Edition 2
# 2025-04-11 09:05:07   Edition: ISO TS 19166 Edition 1
# 2025-04-11 09:05:07   Standard: ISO 19167 The Application of ubiquitous public access for air quality information
# 2025-04-11 09:05:07   Edition: ISO TR 19167 Edition 1
# 2025-04-11 09:05:07   Standard: ISO 19169 Gap-analysis GDF and ISO/TC211
# 2025-04-11 09:05:07   Edition: ISO TR 19169 Edition 1
# 2025-04-11 09:05:08   Standard: ISO 19170 Discrete global grid systems
# 2025-04-11 09:05:08   Edition: ISO 19170-1 Edition 1
# 2025-04-11 09:05:09   Standard: ISO 19174 Securing interoperability among heterogeneous city domain information models
# 2025-04-11 09:05:09   Edition: ISO/TR 19174 Edition 1
# 2025-04-11 09:05:09   Standard: ISO 19178 Training Data Markup Language for Artificial Intelligence
# 2025-04-11 09:05:09   Edition: ISO/FDIS 19178-1 Edition 1
# 2025-04-11 09:05:09   Standard: Informative
# 2025-04-11 09:05:09   Edition: Extended Metadata from 19115
# 2025-04-11 09:05:09   Edition: ISO 19160 Profiles
# 2025-04-11 09:05:09   Edition: ISO GDF
# 2025-04-11 09:05:09   Edition: Open GIS Consortium
# 2025-04-11 09:05:09   Edition: Other Location Services
# 2025-04-11 09:05:10   Edition: Spatial Examples from ISO 19107
# 2025-04-11 09:05:10   Edition: Xamples
# 2025-04-11 09:05:10   Standard: Orphans
# 2025-04-11 09:05:10   Edition: Orphans
# 2025-04-11 09:05:11   Edition: New
# 2025-04-11 09:05:11   Edition: Templates Used

# %% [markdown]
#  # Create DataFrame for properties
#  - Loop through the complete model:
#     - For each attribute or association end: add content to rows for elementID, GUID, main standard, standard, attribute/association name and refElementIDIdentifies all properties and which element it is referring to.
#
# Only navigable aggregation and association ends are considered. All other types of connectors are ignored.
# - Dependencies and realisations are considered more weak relations
# - Generalizations may be relevant on the specialization side

# %%
# This script lists all properties (attributes and association ends) in the whole HM
# NOTE: Only navigable aggregation and association ends are considered. All other types of connectors are ignored.
# Dependencies and realisations are considered more weak relations
# Generalizations may be relevant from the specialization side

def recProperties(pck,df):
    for eaEl in pck.Elements:
        # print('Element: ' + el.Name)
        if eaEl.Type.upper() in ["CLASS","INTERFACE", "DATATYPE","ENUMERATION"]:
            for eaProp in eaEl.Attributes:
                df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID,edPck.Name, eaProp.Name,'Attribute',eaProp.ClassifierID] 
             #Loop for connector dependencies
            for eaCon in eaEl.Connectors:
                if eaCon.Type in ['Aggregation','Association','Generalization']:
                    if eaCon.SupplierID == eaEl.ElementID:
                        cEnd = eaCon.ClientEnd
                        ClassifierID = eaCon.ClientID 
                    else:
                        cEnd = eaCon.SupplierEnd
                        ClassifierID = eaCon.SupplierID

                    if (not cEnd.Navigable == 'Non-Navigable') or (eaCon.Type == 'Generalization'): # and eaCon.ClientID == eaEl.ElementID):
                        df.loc[len(df)] = [eaEl.ElementID, eaEl.ElementGUID, stPck.PackageGUID, stPck.Name,edPck.PackageGUID,edPck.Name, cEnd.Role,eaCon.Type,ClassifierID] 


    for p in pck.Packages:
        recProperties(p,df)
    return df

dfProp = pd.DataFrame(columns=['ElementID','GUID','msGUID','MainStandard','edGUID', 'Edition', 'PropertyName','Type','refElementID'])
# 'ElementID' = Internal ElementID for the classifier that the property is part of
# 'GUID' = GUID for the classifiser
# 'msGUID'= GUID for the main standard (e.g. GUID for the package ISO 19115 Metadata)
# 'MainStandard' = Name of the main standard
# 'edGUID' = GUID for the edition package (e.g. the GUID for the package ISO 19115-1 Edition 1 (Amendment 1
# 'Edition'= Name of the edition
# 'PropertyName' =  Name of the property
# 'Type' = Type of property (attribute, association, aggregation etc)
# 'refElementID' = The ElementID that the property refers to


for stPck in tcMod.Packages:
    printTS('Standard: ' + stPck.Name)
    if stPck.Elements.Count > 0:
        edPck = stPck
        printTS('Edition: ' + edPck.Name)
        dfProp = recProperties(edPck,dfProp)        
    for edPck in stPck.Packages:
        printTS('Edition: ' + edPck.Name)
        dfProp = recProperties(edPck,dfProp)
# Out:
# 2025-04-11 09:05:34   Standard: Common types
# 2025-04-11 09:05:34   Standard: Package Context Diagrams
# 2025-04-11 09:05:34   Standard: ISO 6709 Standard representation of geographic point location by coordinates
# 2025-04-11 09:05:35   Edition: ISO 6709 Edition 2
# 2025-04-11 09:05:35   Edition: ISO 6709 Edition 1 (Corrigendum 1)
# 2025-04-11 09:05:35   Standard: ISO 19101 Reference model
# 2025-04-11 09:05:35   Edition: ISO 19101-1 Edition 1
# 2025-04-11 09:05:35   Edition: ISO 19101-2 Edition 1
# 2025-04-11 09:05:35   Edition: ISO/TS 19101-2 Edition 1
# 2025-04-11 09:05:36   Standard: ISO 19103 Conceptual schema language
# 2025-04-11 09:05:36   Edition: ISO 19103 Edition 2
# 2025-04-11 09:05:36   Edition: ISO 19103 Edition 2 Informative content
# 2025-04-11 09:05:37   Edition: ISO 19103 Edition 1
# 2025-04-11 09:05:39   Edition: ISO TS 19103 Edition 1
# 2025-04-11 09:05:40   Standard: ISO 19104 Terminology
# 2025-04-11 09:05:40   Edition: ISO 19104 Edition 1
# 2025-04-11 09:05:40   Standard: ISO 19105 Conformance and testing
# 2025-04-11 09:05:40   Edition: ISO 19105-2 Extended for normative statements
# 2025-04-11 09:05:41   Edition: ISO 19105 Edition 2
# 2025-04-11 09:05:41   Standard: ISO 19107 Spatial schema
# 2025-04-11 09:05:41   Edition: Informative Annex to Spatial Schema
# 2025-04-11 09:05:41   Edition: Possible Excess Model Elements
# 2025-04-11 09:05:41   Edition: WKT for Features and their Geometry
# 2025-04-11 09:05:41   Edition: ISO 19107 Edition 2
# 2025-04-11 09:05:45   Edition: ISO 19107 Edition 1
# 2025-04-11 09:05:47   Standard: ISO 19108 Temporal schema
# 2025-04-11 09:05:47   Edition: ISO 19108 Edition 1
# 2025-04-11 09:05:48   Standard: ISO 19109 Rules for application schema
# 2025-04-11 09:05:48   Edition: ISO/FDIS 19109 Edition 3
# 2025-04-11 09:05:48   Edition: ISO/FDIS 19109 Edition 3 Informative content
# 2025-04-11 09:05:50   Edition: ISO 19109 Edition 2
# 2025-04-11 09:05:52   Edition: ISO 19109 Edition 1
# 2025-04-11 09:05:52   Standard: ISO 19110 Methodology for feature cataloguing
# 2025-04-11 09:05:52   Edition: ISO 19110 Edition 2
# 2025-04-11 09:05:53   Edition: ISO 19110 Edition 1
# 2025-04-11 09:05:54   Standard: ISO 19111 Referencing by coordinates
# 2025-04-11 09:05:54   Edition: ISO 19111 Edition 3 (Amendment 2)
# 2025-04-11 09:05:55   Edition: ISO 19111 Edition 3 (Amendment 1)
# 2025-04-11 09:05:57   Edition: ISO 19111 Edition 3
# 2025-04-11 09:05:59   Edition: ISO 19111 Edition 2
# 2025-04-11 09:06:00   Edition: ISO 19111-2 Edition 1
# 2025-04-11 09:06:00   Standard: ISO 19112 Spatial referencing by geographic identifier
# 2025-04-11 09:06:00   Edition: ISO 19112 Edition 1
# 2025-04-11 09:06:00   Edition: ISO 19112 Edition 2
# 2025-04-11 09:06:00   Standard: ISO 19115 Metadata
# 2025-04-11 09:06:00   Edition: ISO/AWI 19115-1 Edition 2
# 2025-04-11 09:06:04   Edition: ISO 19115-1 Edition 1 (Complete)
# 2025-04-11 09:06:08   Edition: ISO 19115-2 Edition 2 (Complete)
# 2025-04-11 09:06:09   Edition: ISO 19115-1 Edition 1 (Amendment 2)
# 2025-04-11 09:06:09   Edition: ISO 19115-1 Edition 1
# 2025-04-11 09:06:13   Edition: ISO 19115-1 Edition 1 (Amendment 1)
# 2025-04-11 09:06:14   Edition: ISO 19115-2 Edition 2 (Amendment 1)
# 2025-04-11 09:06:14   Edition: ISO 19115-2 Edition 2
# 2025-04-11 09:06:15   Edition: ISO 19115-2 Edition 1
# 2025-04-11 09:06:16   Edition: ISO 19115 Edition 1 (Corrigendum 1)
# 2025-04-11 09:06:19   Edition: ISO 19115 Edition 1
# 2025-04-11 09:06:23   Standard: ISO 19116 Positioning services
# 2025-04-11 09:06:23   Edition: ISO/FDIS 19116 Edition 3
# 2025-04-11 09:06:23   Edition: ISO 19116 Edition 2 (Amendment 1)
# 2025-04-11 09:06:24   Edition: ISO 19116 Edition 2
# 2025-04-11 09:06:25   Edition: ISO 19116 Edition 1
# 2025-04-11 09:06:26   Standard: ISO 19117 Portrayal
# 2025-04-11 09:06:26   Edition: ISO 19117 Edition 2
# 2025-04-11 09:06:27   Edition: ISO 19117 Edition 1
# 2025-04-11 09:06:27   Standard: ISO 19118 Encoding
# 2025-04-11 09:06:27   Edition: ISO 19118 Edition 2
# 2025-04-11 09:06:27   Edition: ISO 19118 Edition 1
# 2025-04-11 09:06:28   Standard: ISO 19119 Services
# 2025-04-11 09:06:28   Edition: ISO 19119 Edition 2
# 2025-04-11 09:06:28   Edition: ISO 19119 Edition 1 (Amendment 1)
# 2025-04-11 09:06:28   Edition: ISO 19119 Edition 1
# 2025-04-11 09:06:28   Standard: ISO 19123 Schema for coverage geometry and functions
# 2025-04-11 09:06:28   Edition: ISO/DTS 19123-4 Edition 1
# 2025-04-11 09:06:29   Edition: ISO/CD 19123-2 Edition 2
# 2025-04-11 09:06:30   Edition: ISO 19123-1 Edition 1
# 2025-04-11 09:06:31   Edition: ISO 19123-2 Edition 1
# 2025-04-11 09:06:31   Edition: ISO 19123-3 Edition 1
# 2025-04-11 09:06:31   Edition: ISO 19123 Edition 1
# 2025-04-11 09:06:32   Standard: ISO 19124 Calibration and validation of remote sensing data and derived products
# 2025-04-11 09:06:32   Edition: ISO/DTS 19124-2 Edition 1
# 2025-04-11 09:06:33   Edition: ISO TS 19124-1 Edition 1
# 2025-04-11 09:06:34   Standard: ISO 19125 Simple feature access
# 2025-04-11 09:06:34   Edition: ISO 19125-1 Edition 2
# 2025-04-11 09:06:34   Edition: ISO 19125-1 Edition 1
# 2025-04-11 09:06:34   Standard: ISO 19126 Feature concept dictionaries and registers
# 2025-04-11 09:06:34   Edition: ISO 19126 Edition 2
# 2025-04-11 09:06:34   Edition: ISO 19126 Edition 1
# 2025-04-11 09:06:34   Standard: ISO 19128 Web map server interface
# 2025-04-11 09:06:34   Edition: ISO 19128 Edition 1
# 2025-04-11 09:06:34   Standard: ISO 19129 Imagery, gridded and coverage data framework
# 2025-04-11 09:06:34   Edition: ISO 19129 Edition 1
# 2025-04-11 09:06:35   Standard: ISO 19130 Imagery sensor models for geopositioning
# 2025-04-11 09:06:35   Edition: ISO/CD 19130-2 Edition 2
# 2025-04-11 09:06:38   Edition: ISO 19130-1 Edition 1
# 2025-04-11 09:06:39   Edition: ISO 19130 Edition 1
# 2025-04-11 09:06:41   Edition: ISO 19130-2 Edition 1
# 2025-04-11 09:06:43   Standard: ISO 19131 Data product specifications
# 2025-04-11 09:06:43   Edition: ISO 19131 Edition 2
# 2025-04-11 09:06:45   Edition: ISO 19131 Edition 1
# 2025-04-11 09:06:46   Standard: ISO 19132 Location-based services - Reference model
# 2025-04-11 09:06:46   Edition: ISO 19132 Edition 1
# 2025-04-11 09:06:47   Standard: ISO 19133 Location-based services - Tracking and navigation
# 2025-04-11 09:06:47   Edition: ISO 19133 Edition 1
# 2025-04-11 09:06:52   Standard: ISO 19134 Location-based services - Multimodal routing and navigation
# 2025-04-11 09:06:52   Edition: ISO 19134 Edition 1
# 2025-04-11 09:06:53   Standard: ISO 19135 Procedures for item registration
# 2025-04-11 09:06:53   Edition: ISO/CD 19135 Edition 2
# 2025-04-11 09:06:54   Edition: ISO 19135-1 Edition 1
# 2025-04-11 09:06:55   Edition: ISO 19135 Edition 1
# 2025-04-11 09:06:56   Standard: ISO 19136 Geography Markup Language (GML)
# 2025-04-11 09:06:56   Edition: ISO 19136 Edition 1
# 2025-04-11 09:06:59   Standard: ISO 19137 Core profile of the spatial schema
# 2025-04-11 09:06:59   Edition: ISO 19137 Edition 1
# 2025-04-11 09:06:59   Standard: ISO 19139 Metadata - XML schema implementation
# 2025-04-11 09:06:59   Edition: ISO 19139 Edition 1
# 2025-04-11 09:07:00   Edition: ISO 19139-2 Edition 1
# 2025-04-11 09:07:00   Standard: ISO 19141 Schema for moving features
# 2025-04-11 09:07:00   Edition: ISO 19141 Edition 1
# 2025-04-11 09:07:00   Standard: ISO 19144 Classification systems
# 2025-04-11 09:07:00   Edition: ISO TS 19144-3 Edition 1
# 2025-04-11 09:07:05   Edition: ISO/FDIS 19144-2  Edition 2
# 2025-04-11 09:07:11   Edition: ISO 19144-1 Edition 1
# 2025-04-11 09:07:12   Edition: ISO 19144-2 Edition 1
# 2025-04-11 09:07:17   Standard: ISO 19145 Registry of representations of geographic point location
# 2025-04-11 09:07:17   Edition: ISO 19145 Edition 1
# 2025-04-11 09:07:17   Standard: ISO 19146 Cross-domain vocabularies
# 2025-04-11 09:07:17   Edition: ISO 19146 Edition 2
# 2025-04-11 09:07:18   Edition: ISO 19146 Edition 1
# 2025-04-11 09:07:18   Standard: ISO 19147 Transfer Nodes
# 2025-04-11 09:07:18   Edition: ISO 19147 Edition 1
# 2025-04-11 09:07:21   Standard: ISO 19148 Linear Referencing
# 2025-04-11 09:07:21   Edition: ISO 19148 Edition 2
# 2025-04-11 09:07:23   Edition: ISO 19148 Edition 1
# 2025-04-11 09:07:24   Standard: ISO 19150 Ontology
# 2025-04-11 09:07:24   Edition: ISO 19150-4 Edition 1
# 2025-04-11 09:07:25   Edition: ISO/DIS 19150-6 Edition 1
# 2025-04-11 09:07:26   Standard: ISO 19152 Land Administration Domain Model (LADM)
# 2025-04-11 09:07:26   Edition: ISO 19152-1 Edition 1
# 2025-04-11 09:07:28   Edition: ISO/FDIS 19152-2 Edition 1
# 2025-04-11 09:07:40   Edition: ISO 19152-3 Edition 1
# 2025-04-11 09:07:43   Edition: ISO/FDIS 19152-4 Edition 1
# 2025-04-11 09:07:51   Edition: ISO/FDIS 19152-5 Edition 1
# 2025-04-11 09:07:55   Edition: ISO 19152-6 Edition 1
# 2025-04-11 09:07:55   Edition: ISO 19152 Edition 1
# 2025-04-11 09:08:15   Standard: ISO 19153 Geospatial Digital Rights Management Reference Model (GeoDRM RM)
# 2025-04-11 09:08:15   Edition: ISO 19153 Edition 1
# 2025-04-11 09:08:24   Standard: ISO 19154 Ubiquitous public access - Reference model
# 2025-04-11 09:08:24   Edition: ISO 19154 Edition 1
# 2025-04-11 09:08:25   Standard: ISO 19155 Place Identifier (PI) architecture
# 2025-04-11 09:08:25   Edition: ISO 19155 Edition 1
# 2025-04-11 09:08:25   Edition: ISO 19155-2 Edition 1
# 2025-04-11 09:08:25   Standard: ISO 19156 Observations and measurements
# 2025-04-11 09:08:25   Edition: ISO 19156 Edition 2
# 2025-04-11 09:08:27   Edition: ISO 19156 Edition 1
# 2025-04-11 09:08:29   Standard: ISO 19157 Data quality
# 2025-04-11 09:08:29   Edition: ISO 19157-1 Edition 1
# 2025-04-11 09:08:30   Edition: ISO/DIS 19157-3 Edition 1
# 2025-04-11 09:08:31   Edition: ISO 19157 Edition 1 (Amendment 1)
# 2025-04-11 09:08:31   Edition: ISO 19157 Edition 1
# 2025-04-11 09:08:32   Standard: ISO 19159 Calibration and validation of remote sensing imagery sensors and data
# 2025-04-11 09:08:32   Edition: ISO 19159-1 Edition 1
# 2025-04-11 09:08:46   Edition: ISO 19159-3 Edition 1
# 2025-04-11 09:08:47   Edition: ISO/TS 19159-4 Edition 1
# 2025-04-11 09:08:49   Standard: ISO 19160 Addressing
# 2025-04-11 09:08:49   Edition: ISO 19160-1 Edition 1
# 2025-04-11 09:08:52   Edition: ISO 19160-3 Edition 1
# 2025-04-11 09:08:52   Edition: ISO 19160-4 Edition 2
# 2025-04-11 09:08:54   Edition: ISO 19160-4 Edition 1
# 2025-04-11 09:08:56   Edition: ISO 19160-6 Edition 1
# 2025-04-11 09:08:56   Standard: ISO 19163 Content components and encoding rules for imagery and gridded data
# 2025-04-11 09:08:56   Edition: ISO 19163-2 Edition 2
# 2025-04-11 09:08:56   Edition: ISO 19163-1 Edition 1
# 2025-04-11 09:09:00   Standard: ISO 19164 Indoor feature model
# 2025-04-11 09:09:00   Edition: ISO/FDIS 19164 Edition 1
# 2025-04-11 09:09:02   Standard: ISO 19165 Preservation of digital data and metadata
# 2025-04-11 09:09:02   Edition: ISO 19165-2 Edition 1
# 2025-04-11 09:09:02   Edition: ISO 19165-1 Edition 1
# 2025-04-11 09:09:04   Standard: ISO 19166 BIM to GIS conceptual mapping (B2GM)
# 2025-04-11 09:09:04   Edition: ISO/CD TS 19166 Edition 2
# 2025-04-11 09:09:05   Edition: ISO TS 19166 Edition 1
# 2025-04-11 09:09:06   Standard: ISO 19167 The Application of ubiquitous public access for air quality information
# 2025-04-11 09:09:06   Edition: ISO TR 19167 Edition 1
# 2025-04-11 09:09:07   Standard: ISO 19169 Gap-analysis GDF and ISO/TC211
# 2025-04-11 09:09:07   Edition: ISO TR 19169 Edition 1
# 2025-04-11 09:09:12   Standard: ISO 19170 Discrete global grid systems
# 2025-04-11 09:09:12   Edition: ISO 19170-1 Edition 1
# 2025-04-11 09:09:15   Standard: ISO 19174 Securing interoperability among heterogeneous city domain information models
# 2025-04-11 09:09:15   Edition: ISO/TR 19174 Edition 1
# 2025-04-11 09:09:15   Standard: ISO 19178 Training Data Markup Language for Artificial Intelligence
# 2025-04-11 09:09:15   Edition: ISO/FDIS 19178-1 Edition 1
# 2025-04-11 09:09:16   Standard: Informative
# 2025-04-11 09:09:16   Edition: Extended Metadata from 19115
# 2025-04-11 09:09:17   Edition: ISO 19160 Profiles
# 2025-04-11 09:09:17   Edition: ISO GDF
# 2025-04-11 09:09:18   Edition: Open GIS Consortium
# 2025-04-11 09:09:18   Edition: Other Location Services
# 2025-04-11 09:09:19   Edition: Spatial Examples from ISO 19107
# 2025-04-11 09:09:20   Edition: Xamples
# 2025-04-11 09:09:21   Standard: Orphans
# 2025-04-11 09:09:21   Edition: Orphans
# 2025-04-11 09:09:22   Edition: New
# 2025-04-11 09:09:22   Edition: Templates Used

# %%
#Print statistics for property types
dfpropCounts = dfProp.groupby(['Type'])['ElementID'].count().reset_index()
dfpropCounts
# Out:
#              Type  ElementID
# 0     Aggregation       1084
# 1     Association       4445
# 2       Attribute      17035
# 3  Generalization       7476

# %% [markdown]
# # Count references to each element
# - per element
# - per element and edition
# - per element and main standard

# %%
# NOTE: The output of this script is dfElStat, which becommes the sheet Elements in Excel

# Count the total number of references to each element. 
# Group by referenced element (refElementID) and count references from (ElementID)
dfElCounts = dfProp.groupby(['refElementID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'TotalReferences'}, inplace=True)
# print(dfElCounts)
# Merge the statistics (TotalReferences) to the Element table 
result_df = pd.merge(dfEl, dfElCounts, left_on='ElementID', right_on='refElementID', how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'TotalReferences':0},inplace=True)
result_df['TotalReferences'] = result_df['TotalReferences'].astype(int)
dfElStat = result_df

# Count the total number of references from each edition package to each element
# Group by Edition (edGUID) and the referenced Element (refElement)
dfElCounts = dfProp.groupby(['refElementID','edGUID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'EditionInternalReferences'}, inplace=True)
# Merge the statistics to the Element table by joining on ElementID and Edition (edGUID)
# NOTE: This join gives the number of references to the elements from elements within the same edition package (internal references)
result_df = pd.merge(dfElStat, dfElCounts, left_on=['ElementID','edGUID'], right_on=['refElementID','edGUID'], how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'EditionInternalReferences':0},inplace=True)
result_df['EditionInternalReferences'] = result_df['EditionInternalReferences'].astype(int)
dfElStat = result_df

# Count the total number of references from each main standards package to each element
# Group by msGUID and the referenced Element (refElement)
dfElCounts = dfProp.groupby(['refElementID','msGUID'])['ElementID'].count().reset_index()
dfElCounts.rename(columns={'ElementID': 'StandardInternalReferences'}, inplace=True)
# Merge on the edGUID and refElement
# NOTE: This join gives the number of references to the elements from elements within the same main standard package (standard internal references)
result_df = pd.merge(dfElStat, dfElCounts, left_on=['ElementID','msGUID'], right_on=['refElementID','msGUID'], how='left')
result_df.drop(columns=['refElementID'], inplace=True)
result_df.fillna({'StandardInternalReferences':0},inplace=True)
result_df['StandardInternalReferences'] = result_df['StandardInternalReferences'].astype(int)
dfElStat = result_df
# Count external references (The difference between standard internal and the total)
dfElStat['ExternalReferences'] = dfElStat['TotalReferences'] - dfElStat['StandardInternalReferences']
# dfElStat.drop(columns=['StandardInternalReferences','EditionInternalReferences'], inplace=True)

# %%
# Statistics per element name per main standard (to summarize all references for different versions of the same element)
# # NOTE: The output of this script is elStatByName, which becommes the sheet Element by standard in Excel

elStatByName = dfElStat.groupby(['msGUID', 'MainStandard','ElementName']).agg(
    Versions=pd.NamedAgg(column='ElementID', aggfunc='count'),
    ExternalReferences=pd.NamedAgg(column='ExternalReferences', aggfunc='sum'),
    TotalReferences=pd.NamedAgg(column='TotalReferences', aggfunc='sum')
).reset_index()

# %%
# Extend the properties dataframe with element name, edition etc for the referenced element 

dfRefEls = dfElStat[['ElementID','ElementName','msGUID','MainStandard','edGUID','Edition']].add_prefix('ref')
dfPropWithNames = pd.merge(dfProp, dfRefEls, left_on='refElementID', right_on='refElementID', how='left')
print(str(len(dfPropWithNames)))
# Add the total number of references for referenced elements
dfRefElStat= elStatByName.add_prefix('count')
dfPropWithNames = pd.merge(dfPropWithNames, dfRefElStat, left_on=['refMainStandard','refElementName'], right_on=['countMainStandard','countElementName'], how='left')
dfPropWithNames.drop(columns=['countMainStandard','countElementName','countmsGUID'], inplace=True)
# dfPropWithNames.rename(columns={'countExternalReferences': 'refExternalReferences'}, inplace=True)
# Out:
# 30040

# %%
# More statistics: Number of external editions and external mian standards that refer to each element

#Create filtered DataFrame with only properties that refer to an element outside of its main standard 
filtered_dfPropWithNames = dfPropWithNames[(dfPropWithNames['MainStandard'] != dfPropWithNames['refMainStandard']) & (dfPropWithNames['refElementID'] != 0)]
print(str(len(filtered_dfPropWithNames)))

# Count the number of external editions that refer to each element                                   
# Group dfPropCounts by refElementID and edGUID
result_df = filtered_dfPropWithNames.groupby(['refElementID','edGUID'])['ElementID'].count().reset_index()
result_df.drop(columns=['ElementID'], inplace=True)
dfPropCounts = result_df
print(dfPropCounts.head())
# Group the result by refElementID, count edGUID
result_df = dfPropCounts.groupby(['refElementID'])['edGUID'].count().reset_index()
dfPropCounts = result_df
dfPropCounts.rename(columns={'edGUID': 'countExternalEditions'}, inplace=True)
# Merge (Left join) to dfPropWithNames
print(dfPropCounts.head())
result_df = pd.merge(dfPropWithNames, dfPropCounts, left_on='refElementID', right_on='refElementID', how='left')
result_df.fillna({'countExternalEditions':0},inplace=True)
result_df['countExternalEditions'] = result_df['countExternalEditions'].astype(int)
dfPropWithNames = result_df

#Count the number of external standards that refer to each element
# Group filtered_dfPropWithNames by refElementID and msGUID
result_df = filtered_dfPropWithNames.groupby(['refElementID','msGUID'])['ElementID'].count().reset_index()
result_df.drop(columns=['ElementID'], inplace=True)
dfPropCounts = result_df
print(dfPropCounts.head())
# Group the result by refElementID, count msGUID
result_df = dfPropCounts.groupby(['refElementID'])['msGUID'].count().reset_index()
dfPropCounts = result_df
dfPropCounts.rename(columns={'msGUID': 'countExternalStandards'}, inplace=True)
# Merge (Left join) to dfPropWithNames
print(dfPropCounts.head())
result_df = pd.merge(dfPropWithNames, dfPropCounts, left_on='refElementID', right_on='refElementID', how='left')
result_df.fillna({'countExternalStandards':0},inplace=True)
result_df['countExternalStandards'] = result_df['countExternalStandards'].astype(int)
dfPropWithNames = result_df

# TODO
# Count the number og individual editions and main standard that refer to an element based on unique names per main standard
# Group dfPropCounts by refmsGUID, refElementName and edGUID
result_df = filtered_dfPropWithNames.groupby(['refmsGUID','refElementName','edGUID'])['ElementID'].count().reset_index()
result_df.drop(columns=['ElementID'], inplace=True)
dfPropCounts = result_df
print(dfPropCounts.head())
# Group the result by refElementName, count edGUID
result_df = dfPropCounts.groupby(['refmsGUID','refElementName'])['edGUID'].count().reset_index()
dfPropCounts = result_df
dfPropCounts.rename(columns={'edGUID': 'countExternalEditionsName'}, inplace=True)
# Merge (Left join) to dfPropWithNames
print(dfPropCounts.head())
result_df = pd.merge(dfPropWithNames, dfPropCounts, left_on=['refmsGUID','refElementName'], right_on=['refmsGUID','refElementName'], how='left')
result_df.fillna({'countExternalEditionsName':0},inplace=True)
result_df['countExternalEditionsName'] = result_df['countExternalEditionsName'].astype(int)
dfPropWithNames = result_df
# Merge to elStatbyName on msGUID and refElementName - for statistics


# Group dfPropCounts by refElementName and msGUID
result_df = filtered_dfPropWithNames.groupby(['refmsGUID','refElementName','msGUID'])['ElementID'].count().reset_index()
result_df.drop(columns=['ElementID'], inplace=True)
dfPropCounts = result_df
print(dfPropCounts.head())
# Group the result by refElementName, count msGUID
result_df = dfPropCounts.groupby(['refmsGUID','refElementName'])['msGUID'].count().reset_index()
dfPropCounts = result_df
dfPropCounts.rename(columns={'msGUID': 'countExternalStandardsName'}, inplace=True)
# Merge (Left join) to dfPropWithNames
print(dfPropCounts.head())
result_df = pd.merge(dfPropWithNames, dfPropCounts, left_on=['refmsGUID','refElementName'], right_on=['refmsGUID','refElementName'], how='left')
result_df.fillna({'countExternalStandardsName':0},inplace=True)
result_df['countExternalStandardsName'] = result_df['countExternalStandardsName'].astype(int)
dfPropWithNames = result_df
# Merge to elStatbyName on msGUID and refElementName - for statistics



#Create filtered DataFrame with only properties that refer to an element outside of its main standard and where that element is being referred to by at least 5 external properties
# filtered_dfPropWithNames = dfPropWithNames[(dfPropWithNames['MainStandard'] != dfPropWithNames['refMainStandard']) & (dfPropWithNames['countExternalReferences'] >= 5)]
# print(str(len(filtered_dfPropWithNames)))
# Out:
# 6523
#    refElementID                                  edGUID
# 0            64  {D25A7C1E-8D72-4614-BCF0-2E6C3769853A}
# 1           119  {80442A97-FB74-42b1-92E0-DDAB27EA18F5}
# 2           119  {C6593764-1DF3-44f8-9658-D42F172B225B}
# 3           125  {C6593764-1DF3-44f8-9658-D42F172B225B}
# 4           126  {C6593764-1DF3-44f8-9658-D42F172B225B}
#    refElementID  countExternalEditions
# 0            64                      1
# 1           119                      2
# 2           125                      1
# 3           126                      1
# 4           131                      1
#    refElementID                                  msGUID
# 0            64  {0EBB14A6-285B-440c-B6AF-20A47ACB4D76}
# 1           119  {74404EA6-E630-4be2-B1BB-057C76FD4759}
# 2           125  {74404EA6-E630-4be2-B1BB-057C76FD4759}
# 3           126  {74404EA6-E630-4be2-B1BB-057C76FD4759}
# 4           131  {74404EA6-E630-4be2-B1BB-057C76FD4759}
#    refElementID  countExternalStandards
# 0            64                       1
# 1           119                       1
# 2           125                       1
# 3           126                       1
# 4           131                       1
#                                 refmsGUID              refElementName  \
# 0  {01AF2986-50F9-4d81-8525-59BAABF071CD}  AbsolutePositionalAccuracy
# 1  {01AF2986-50F9-4d81-8525-59BAABF071CD}  AbsolutePositionalAccuracy
# 2  {01AF2986-50F9-4d81-8525-59BAABF071CD}  AccuracyOfATimeMeasurement
# 3  {01AF2986-50F9-4d81-8525-59BAABF071CD}                BasicMeasure
# 4  {01AF2986-50F9-4d81-8525-59BAABF071CD}        DQM_MeasureCatalogue
#
#                                    edGUID
# 0  {0170C834-DE73-4562-B5F8-F7EF39D01DED}
# 1  {26ECD717-BBD1-45f5-BBD3-7BA98D3A12CD}
# 2  {0170C834-DE73-4562-B5F8-F7EF39D01DED}
# 3  {58442767-FC7E-401a-8FB8-EE4686BEFA62}
# 4  {BC933ACB-A617-4784-9DC3-95EA2B6FAADF}
#                                 refmsGUID  \
# 0  {01AF2986-50F9-4d81-8525-59BAABF071CD}
# 1  {01AF2986-50F9-4d81-8525-59BAABF071CD}
# 2  {01AF2986-50F9-4d81-8525-59BAABF071CD}
# 3  {01AF2986-50F9-4d81-8525-59BAABF071CD}
# 4  {01AF2986-50F9-4d81-8525-59BAABF071CD}
#
#                           refElementName  countExternalEditionsName
# 0             AbsolutePositionalAccuracy                          2
# 1             AccuracyOfATimeMeasurement                          1
# 2                           BasicMeasure                          1
# 3                   DQM_MeasureCatalogue                          1
# 4  DQM_RegisteredDataQualityBasicMeasure                          1
#                                 refmsGUID              refElementName  \
# 0  {01AF2986-50F9-4d81-8525-59BAABF071CD}  AbsolutePositionalAccuracy
# 1  {01AF2986-50F9-4d81-8525-59BAABF071CD}  AbsolutePositionalAccuracy
# 2  {01AF2986-50F9-4d81-8525-59BAABF071CD}  AccuracyOfATimeMeasurement
# 3  {01AF2986-50F9-4d81-8525-59BAABF071CD}                BasicMeasure
# 4  {01AF2986-50F9-4d81-8525-59BAABF071CD}        DQM_MeasureCatalogue
#
#                                    msGUID
# 0  {31E40382-64D9-46fd-AB01-96F36E4D6E2B}
# 1  {7A4CC887-A327-4429-8179-2A8725409A3D}
# 2  {31E40382-64D9-46fd-AB01-96F36E4D6E2B}
# 3  {13EDE126-6353-4047-B047-0AFDC2C667E9}
# 4  {E9D6AA79-36CA-42c2-A837-E9706168F7D4}
#                                 refmsGUID  \
# 0  {01AF2986-50F9-4d81-8525-59BAABF071CD}
# 1  {01AF2986-50F9-4d81-8525-59BAABF071CD}
# 2  {01AF2986-50F9-4d81-8525-59BAABF071CD}
# 3  {01AF2986-50F9-4d81-8525-59BAABF071CD}
# 4  {01AF2986-50F9-4d81-8525-59BAABF071CD}
#
#                           refElementName  countExternalStandardsName
# 0             AbsolutePositionalAccuracy                           2
# 1             AccuracyOfATimeMeasurement                           1
# 2                           BasicMeasure                           1
# 3                   DQM_MeasureCatalogue                           1
# 4  DQM_RegisteredDataQualityBasicMeasure                           1

# %% [markdown]
# # Export to Excel

# %%
file_path = mainFolder + '\\HM_Dependencies.xlsx'
# Export to Excel 
writer = pd.ExcelWriter(file_path)

# The list of referenced elements and the count of internal and external references (dfElStat)
dfElStatOut = dfElStat.drop(columns=['ElementID','GUID','msGUID','edGUID'])
dfElStatOut.to_excel(writer,'Elements') 
print(f'Exported elements report to file: {file_path}' + '(count ' +  str(len(dfElStatOut)) + ')' )  

# The list of references with total references per main standard
elStatByNameOut = elStatByName.drop(columns=['msGUID'])
elStatByNameOut.to_excel(writer,'Elements by standard') 
print(f'Exported elements report per main standards to file: {file_path}' + '(count ' +  str(len(elStatByNameOut)) + ')' )  

# The list of properties with the elements they are refering and statistics for that element
dfPropWithNamesOut = dfPropWithNames.drop(columns=['GUID','msGUID','edGUID'])
dfPropWithNamesOut.to_excel(writer,'Properties') 
print(f'Exported properties report to file: {file_path}' + '(count ' +  str(len(dfPropWithNamesOut)) + ')' )  

# Properties that refer to an element outside of its main standard
# and where that element is being referred to by at least 5 properties
filtered_dfPropWithNames = filtered_dfPropWithNames.drop(columns=['GUID','msGUID','edGUID'])
filtered_dfPropWithNames.to_excel(writer,'PropertiesExternal') 
print(f'Exported filtered properties report to file: {file_path} ' + '(count ' +  str(len(filtered_dfPropWithNames)) + ')' ) 

writer.close()
# Out:
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_1080\3295461545.py:7: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   dfElStatOut.to_excel(writer,'Elements')
# Exported elements report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\HM_Dependencies.xlsx(count 7486)
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_1080\3295461545.py:12: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   elStatByNameOut.to_excel(writer,'Elements by standard')
# Exported elements report per main standards to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\HM_Dependencies.xlsx(count 5343)
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_1080\3295461545.py:17: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   dfPropWithNamesOut.to_excel(writer,'Properties')
# Exported properties report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\HM_Dependencies.xlsx(count 30040)
# C:\Users\JETKNU\AppData\Local\Temp\ipykernel_1080\3295461545.py:23: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   filtered_dfPropWithNames.to_excel(writer,'PropertiesExternal')
# Exported filtered properties report to file: C:\Data\GitHub\ISO TC211\HMMG\EditorialVersion\HM_Dependencies.xlsx (count 6523)
